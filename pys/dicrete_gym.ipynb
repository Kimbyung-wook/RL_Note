# %%
# Find RL_Note path and append sys path
import os, sys
cwd = os.getcwd()
pos = cwd.find('RL_Note')
root_path = cwd[0:pos] + 'RL_Note'
sys.path.append(root_path)
print(root_path)
workspace_path = root_path + "\\pys"
# Out:
# e:\MyNote\RL_Note

# %%
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
from env_config  import env_configs
from pys.agent.dqn_agent import DQNAgent
from pys.agent.mdqn_agent import MDQNAgent

# %%
cfg = {\
        # "ENV":"Pong-v0",\
        "ENV":"CartPole-v1",\
        "RL":{
            "ALGORITHM":"MDQN",\
            "NETWORK":{
                "LAYER":[255,255]
            }
        },\
        "ER":"ER",\
        "HER":\
            {
                "REPLAY_N":8,\
                "STRATEGY":"EPISODE",\
                # "REWARD_FUNC":reward_function,\
                # "DONE_FUNC":done_function,\
            },\
        "BATCH_SIZE":8,\
        "TRAIN_START":500,\
        "MEMORY_SIZE":10000,\
        }
env_config = env_configs[cfg["ENV"]]
if cfg["ER"] == "HER":
    FILENAME = cfg["ENV"] + '_' + cfg["RL"]["ALGORITHM"] + '_' + cfg["ER"] + '_' + cfg["HER"]["STRATEGY"]
else:
    FILENAME = cfg["ENV"] + '_' + cfg["RL"]["ALGORITHM"] + '_' + cfg["ER"]
EPISODES = env_config["EPISODES"]
END_SCORE = env_config["END_SCORE"]

# %%
# %matplotlib tk

figure = plt.gcf()
figure.set_size_inches(8,6)
env = gym.make(cfg["ENV"])
if cfg["RL"]["ALGORITHM"] == "DQN":
    agent = DQNAgent(env, cfg)
elif cfg["RL"]["ALGORITHM"] == "A2C":
    agent = A2CAgent(env, cfg)
elif cfg["RL"]["ALGORITHM"] == "MDQN":
    agent = MDQNAgent(env, cfg)
    
if __name__ == "__main__":
    scores_avg, scores_raw, episodes, losses = [], [], [], []
    epsilons = []
    score_avg = 0
    end = False
    show_media_info = True
    goal = np.array([1.0,0.0,0.0])
    
    for e in range(EPISODES):
        # Episode initialization
        done = False
        score = 0
        loss_list = []
        state = env.reset()
        while not done:
            # env.render()
            # Interact with env.
            action = agent.get_action(state)
            next_state, reward, done, info = env.step(action)
            agent.remember(state, action, reward, next_state, done, goal)
            loss = agent.train_model()
            agent.update_network()
            state = next_state
            # 
            score += reward
            loss_list.append(loss)
            if show_media_info:
                print("-------------- Variable shapes --------------")
                print("State Shape : ", np.shape(state))
                print("Action Shape : ", np.shape(action))
                print("Reward Shape : ", np.shape(reward))
                print("done Shape : ", np.shape(done))
                print("---------------------------------------------")
                show_media_info = False
            if done:
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print("episode: {0:3d} | score avg: {1:3.2f} | mem size {2:6d} |"
                    .format(e, score_avg, len(agent.memory)))

                episodes.append(e)
                scores_avg.append(score_avg)
                scores_raw.append(score)
                losses.append(np.mean(loss_list))
                epsilons.append(agent.epsilon)
                # View data
                plt.clf()
                plt.subplot(311)
                plt.plot(episodes, scores_avg, 'b')
                plt.plot(episodes, scores_raw, 'b', alpha=0.8, linewidth=0.5)
                plt.xlabel('episode'); plt.ylabel('average score'); plt.grid()
                plt.title(cfg["ENV"] +'_' + cfg["RL"]["ALGORITHM"] +'_' + cfg["ER"])
                plt.subplot(312)
                plt.plot(episodes, epsilons, 'b')
                plt.xlabel('episode'); plt.ylabel('epsilon'); plt.grid()
                plt.subplot(313)
                plt.plot(episodes, losses, 'b')
                plt.xlabel('episode'); plt.ylabel('losses') ;plt.grid()
                plt.savefig(workspace_path + "\\result\\img\\" + FILENAME + "_TF.jpg", dpi=100)

                # 이동 평균이 0 이상일 때 종료
                if score_avg > END_SCORE:
                    # agent.save_model(workspace_path + "\\result\\save_model\\")
                    end = True
                    break
        if end == True:
            env.close()
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_epi",  episodes)
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_scores_avg",scores_avg)
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_scores_raw",scores_raw)
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_losses",losses)
            print("End")
            break
# Out:
# CartPole-v1_MDQN_ER
# States 4, Actions 2
# -------------- Variable shapes --------------
# State Shape :  (4,)
# Action Shape :  ()
# Reward Shape :  ()
# done Shape :  ()
# ---------------------------------------------
# episode:   0 | score avg: 19.00 | mem size     19 |
# episode:   1 | score avg: 18.80 | mem size     36 |
# episode:   2 | score avg: 21.62 | mem size     83 |
# episode:   3 | score avg: 21.56 | mem size    104 |
# episode:   4 | score avg: 23.10 | mem size    141 |
# episode:   5 | score avg: 22.09 | mem size    154 |
# episode:   6 | score avg: 20.88 | mem size    164 |
# episode:   7 | score avg: 19.99 | mem size    176 |
# episode:   8 | score avg: 19.20 | mem size    188 |
# episode:   9 | score avg: 18.18 | mem size    197 |
# episode:  10 | score avg: 17.76 | mem size    211 |
# episode:  11 | score avg: 18.58 | mem size    237 |
# episode:  12 | score avg: 17.92 | mem size    249 |
# episode:  13 | score avg: 18.83 | mem size    276 |
# episode:  14 | score avg: 18.45 | mem size    291 |
# episode:  15 | score avg: 17.70 | mem size    302 |
# episode:  16 | score avg: 20.03 | mem size    343 |
# episode:  17 | score avg: 19.43 | mem size    357 |
# episode:  18 | score avg: 19.19 | mem size    374 |
# episode:  19 | score avg: 19.37 | mem size    395 |
# episode:  20 | score avg: 21.03 | mem size    431 |
# episode:  21 | score avg: 21.43 | mem size    456 |
# episode:  22 | score avg: 20.49 | mem size    468 |
# Start to train, check batch shapes
# **** shape of mini_batch (8, 5) <class 'list'>
# **** shape of states (8, 4) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of actions (8,) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of rewards (8, 1) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of next_states (8, 4) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of dones (8, 1) <class 'tensorflow.python.framework.ops.EagerTensor'>
# episode:  23 | score avg: 21.74 | mem size    501 |
# episode:  24 | score avg: 20.86 | mem size    514 |
# episode:  25 | score avg: 20.78 | mem size    534 |
# episode:  26 | score avg: 22.90 | mem size    576 |
# episode:  27 | score avg: 22.01 | mem size    590 |
# episode:  28 | score avg: 23.81 | mem size    630 |
# episode:  29 | score avg: 23.83 | mem size    654 |
# episode:  30 | score avg: 22.64 | mem size    666 |
# episode:  31 | score avg: 21.78 | mem size    680 |
# episode:  32 | score avg: 22.00 | mem size    704 |
# episode:  33 | score avg: 20.60 | mem size    712 |
# episode:  34 | score avg: 19.64 | mem size    723 |
# episode:  35 | score avg: 18.58 | mem size    732 |
# episode:  36 | score avg: 18.32 | mem size    748 |
# episode:  37 | score avg: 18.09 | mem size    764 |
# episode:  38 | score avg: 18.58 | mem size    787 |
# episode:  39 | score avg: 18.52 | mem size    805 |
# episode:  40 | score avg: 18.57 | mem size    824 |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-24cd8599da71> in <module>
#      56                 epsilons.append(agent.epsilon)
#      57                 # View data
# ---> 58                 plt.clf()
#      59                 plt.subplot(311)
#      60                 plt.plot(episodes, scores_avg, 'b')
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\pyplot.py in clf()
#     943 def clf():
#     944     """Clear the current figure."""
# --> 945     gcf().clf()
#     946
#     947
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\figure.py in clf(self, keep_observers)
#    2727
#    2728         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 2729             ax.cla()
#    2730             self.delaxes(ax)         # removes ax from self._axstack
#    2731
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1294         self.set_axis_on()
#    1295
# -> 1296         self.xaxis.set_clip_path(self.patch)
#    1297         self.yaxis.set_clip_path(self.patch)
#    1298
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     913         super().set_clip_path(clippath, transform)
#     914         for child in self.majorTicks + self.minorTicks:
# --> 915             child.set_clip_path(clippath, transform)
#     916         self.stale = True
#     917
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     239     def set_clip_path(self, clippath, transform=None):
#     240         # docstring inherited
# --> 241         super().set_clip_path(clippath, transform)
#     242         self.gridline.set_clip_path(clippath, transform)
#     243         self.stale = True
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     778             if isinstance(path, Rectangle):
#     779                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 780                                                path.get_transform())
#     781                 self._clippath = None
#     782                 success = True
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     271     def get_transform(self):
#     272         """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 273         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     274
#     275     def get_data_transform(self):
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     777         bbox = self.get_bbox()
#     778         return (transforms.BboxTransformTo(bbox)
# --> 779                 + transforms.Affine2D().rotate_deg_around(
#     780                     bbox.x0, bbox.y0, self.angle))
#     781
#
# ~\.conda\envs\TF240\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1878         if matrix is None:
#    1879             # A bit faster than np.identity(3).
# -> 1880             matrix = IdentityTransform._mtx.copy()
#    1881         self._mtx = matrix.copy()
#    1882         self._invalid = 0
#
# KeyboardInterrupt:
