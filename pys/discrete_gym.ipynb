# %%
# Find RL_Note path and append sys path
import os, sys
cwd = os.getcwd()
pos = cwd.find('RL_Note')
root_path = cwd[0:pos] + 'RL_Note'
sys.path.append(root_path)
print(root_path)
workspace_path = root_path + "\\pys"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# e:\MyNote\RL_Note

# %%
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
from env_config  import env_configs
from pys.agent.dqn_agent import DQNAgent
from pys.agent.mdqn_agent import MDQNAgent

# %%
cfg = {\
        # "ENV":"Pong-v0",\
        "ENV":"CartPole-v1",\
        "RL":{
            "ALGORITHM":"MDQN",\
            "NETWORK":{
                "LAYER":[255,255]
            }
        },\
        "ER":"ER",\
        "HER":\
            {
                "REPLAY_N":8,\
                "STRATEGY":"EPISODE",\
                # "REWARD_FUNC":reward_function,\
                # "DONE_FUNC":done_function,\
            },\
        "BATCH_SIZE":8,\
        "TRAIN_START":500,\
        "MEMORY_SIZE":10000,\
        }
env_config = env_configs[cfg["ENV"]]
if cfg["ER"] == "HER":
    FILENAME = cfg["ENV"] + '_' + cfg["RL"]["ALGORITHM"] + '_' + cfg["ER"] + '_' + cfg["HER"]["STRATEGY"]
else:
    FILENAME = cfg["ENV"] + '_' + cfg["RL"]["ALGORITHM"] + '_' + cfg["ER"]
EPISODES = env_config["EPISODES"]
END_SCORE = env_config["END_SCORE"]

# %%
# %matplotlib tk

figure = plt.gcf()
figure.set_size_inches(8,6)
env = gym.make(cfg["ENV"])
if cfg["RL"]["ALGORITHM"] == "DQN":
    agent = DQNAgent(env, cfg)
elif cfg["RL"]["ALGORITHM"] == "A2C":
    agent = A2CAgent(env, cfg)
elif cfg["RL"]["ALGORITHM"] == "MDQN":
    agent = MDQNAgent(env, cfg)
    
if __name__ == "__main__":
    scores_avg, scores_raw, episodes, losses = [], [], [], []
    epsilons = []
    score_avg = 0
    end = False
    show_media_info = True
    goal = np.array([1.0,0.0,0.0])
    
    for e in range(EPISODES):
        # Episode initialization
        done = False
        score = 0
        loss_list = []
        state = env.reset()
        while not done:
            # env.render()
            # Interact with env.
            action = agent.get_action(state)
            next_state, reward, done, info = env.step(action)
            agent.remember(state, action, reward, next_state, done, goal)
            loss = agent.train_model()
            agent.update_network()
            state = next_state
            # 
            score += reward
            loss_list.append(loss)
            if show_media_info:
                print("-------------- Variable shapes --------------")
                print("State Shape : ", np.shape(state))
                print("Action Shape : ", np.shape(action))
                print("Reward Shape : ", np.shape(reward))
                print("done Shape : ", np.shape(done))
                print("---------------------------------------------")
                show_media_info = False
            if done:
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print("episode: {0:3d} | score avg: {1:3.2f} | mem size {2:6d} |"
                    .format(e, score_avg, len(agent.memory)))

                episodes.append(e)
                scores_avg.append(score_avg)
                scores_raw.append(score)
                losses.append(np.mean(loss_list))
                epsilons.append(agent.epsilon)
                # View data
                plt.clf()
                plt.subplot(311)
                plt.plot(episodes, scores_avg, 'b')
                plt.plot(episodes, scores_raw, 'b', alpha=0.8, linewidth=0.5)
                plt.xlabel('episode'); plt.ylabel('average score'); plt.grid()
                plt.title(cfg["ENV"] +'_' + cfg["RL"]["ALGORITHM"] +'_' + cfg["ER"])
                plt.subplot(312)
                plt.plot(episodes, epsilons, 'b')
                plt.xlabel('episode'); plt.ylabel('epsilon'); plt.grid()
                plt.subplot(313)
                plt.plot(episodes, losses, 'b')
                plt.xlabel('episode'); plt.ylabel('losses') ;plt.grid()
                plt.savefig(workspace_path + "\\result\\img\\" + FILENAME + "_TF.jpg", dpi=100)

                # 이동 평균이 0 이상일 때 종료
                if score_avg > END_SCORE:
                    # agent.save_model(workspace_path + "\\result\\save_model\\")
                    end = True
                    break
        if end == True:
            env.close()
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_epi",  episodes)
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_scores_avg",scores_avg)
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_scores_raw",scores_raw)
            # np.save(workspace_path + "\\result\\data\\" + FILENAME + "_TF_losses",losses)
            print("End")
            break
# Out:
# CartPole-v1_MDQN_ER
# States 4, Actions 2
# -------------- Variable shapes --------------
# State Shape :  (4,)
# Action Shape :  ()
# Reward Shape :  ()
# done Shape :  ()
# ---------------------------------------------
# episode:   0 | score avg: 38.00 | mem size     38 |
# episode:   1 | score avg: 36.40 | mem size     60 |
# episode:   2 | score avg: 33.76 | mem size     70 |
# episode:   3 | score avg: 32.68 | mem size     93 |
# episode:   4 | score avg: 33.62 | mem size    135 |
# episode:   5 | score avg: 32.55 | mem size    158 |
# episode:   6 | score avg: 32.20 | mem size    187 |
# episode:   7 | score avg: 30.68 | mem size    204 |
# episode:   8 | score avg: 31.01 | mem size    238 |
# episode:   9 | score avg: 36.91 | mem size    328 |
# episode:  10 | score avg: 34.82 | mem size    344 |
# episode:  11 | score avg: 32.44 | mem size    355 |
# episode:  12 | score avg: 30.69 | mem size    370 |
# episode:  13 | score avg: 30.82 | mem size    402 |
# episode:  14 | score avg: 29.84 | mem size    423 |
# episode:  15 | score avg: 28.76 | mem size    442 |
# episode:  16 | score avg: 26.98 | mem size    453 |
# episode:  17 | score avg: 25.88 | mem size    469 |
# episode:  18 | score avg: 24.80 | mem size    484 |
# Start to train, check batch shapes
# **** shape of mini_batch (8, 5) <class 'list'>
# **** shape of states (8, 4) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of actions (8,) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of rewards (8, 1) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of next_states (8, 4) <class 'tensorflow.python.framework.ops.EagerTensor'>
# **** shape of dones (8, 1) <class 'tensorflow.python.framework.ops.EagerTensor'>
# episode:  19 | score avg: 24.32 | mem size    504 |
# episode:  20 | score avg: 23.78 | mem size    523 |
# episode:  21 | score avg: 22.61 | mem size    535 |
# episode:  22 | score avg: 25.15 | mem size    583 |
# episode:  23 | score avg: 27.83 | mem size    635 |
# episode:  24 | score avg: 26.75 | mem size    652 |
# episode:  25 | score avg: 25.47 | mem size    666 |
# episode:  26 | score avg: 24.53 | mem size    682 |
# episode:  27 | score avg: 25.37 | mem size    715 |
# episode:  28 | score avg: 26.94 | mem size    756 |
# episode:  29 | score avg: 27.74 | mem size    791 |
# episode:  30 | score avg: 26.67 | mem size    808 |
# episode:  31 | score avg: 25.20 | mem size    820 |
# episode:  32 | score avg: 24.38 | mem size    837 |
# episode:  33 | score avg: 23.24 | mem size    850 |
# episode:  34 | score avg: 22.12 | mem size    862 |
# episode:  35 | score avg: 24.31 | mem size    906 |
# episode:  36 | score avg: 26.08 | mem size    948 |
# episode:  37 | score avg: 25.97 | mem size    973 |
# episode:  38 | score avg: 24.77 | mem size    987 |
# episode:  39 | score avg: 23.29 | mem size    997 |
# episode:  40 | score avg: 22.37 | mem size   1011 |
# episode:  41 | score avg: 21.63 | mem size   1026 |
# episode:  42 | score avg: 20.37 | mem size   1035 |
# episode:  43 | score avg: 22.23 | mem size   1074 |
# episode:  44 | score avg: 21.11 | mem size   1085 |
# episode:  45 | score avg: 21.90 | mem size   1114 |
# episode:  46 | score avg: 20.91 | mem size   1126 |
# episode:  47 | score avg: 19.92 | mem size   1137 |
# episode:  48 | score avg: 19.22 | mem size   1150 |
# episode:  49 | score avg: 18.70 | mem size   1164 |
# episode:  50 | score avg: 18.03 | mem size   1176 |
# episode:  51 | score avg: 18.43 | mem size   1198 |
# episode:  52 | score avg: 18.29 | mem size   1215 |
# episode:  53 | score avg: 17.56 | mem size   1226 |
# episode:  54 | score avg: 16.70 | mem size   1235 |
# episode:  55 | score avg: 17.73 | mem size   1262 |
# episode:  56 | score avg: 23.86 | mem size   1341 |
# episode:  57 | score avg: 24.07 | mem size   1367 |
# episode:  58 | score avg: 25.66 | mem size   1407 |
# episode:  59 | score avg: 25.40 | mem size   1430 |
# episode:  60 | score avg: 24.76 | mem size   1449 |
# episode:  61 | score avg: 24.38 | mem size   1470 |
# episode:  62 | score avg: 24.54 | mem size   1496 |
# episode:  63 | score avg: 25.49 | mem size   1530 |
# episode:  64 | score avg: 24.94 | mem size   1550 |
# episode:  65 | score avg: 25.95 | mem size   1585 |
# episode:  66 | score avg: 26.95 | mem size   1621 |
# episode:  67 | score avg: 26.56 | mem size   1644 |
# episode:  68 | score avg: 28.20 | mem size   1687 |
# episode:  69 | score avg: 34.58 | mem size   1779 |
# episode:  70 | score avg: 37.52 | mem size   1843 |
# episode:  71 | score avg: 48.57 | mem size   1991 |
# episode:  72 | score avg: 53.41 | mem size   2088 |
# episode:  73 | score avg: 55.97 | mem size   2167 |
# episode:  74 | score avg: 65.18 | mem size   2315 |
# episode:  75 | score avg: 71.56 | mem size   2444 |
# episode:  76 | score avg: 76.60 | mem size   2566 |
# episode:  77 | score avg: 84.64 | mem size   2723 |
# episode:  78 | score avg: 97.38 | mem size   2935 |
# episode:  79 | score avg: 115.34 | mem size   3212 |
# episode:  80 | score avg: 122.11 | mem size   3395 |
# episode:  81 | score avg: 124.90 | mem size   3545 |
# episode:  82 | score avg: 131.61 | mem size   3737 |
# episode:  83 | score avg: 136.95 | mem size   3922 |
# episode:  84 | score avg: 141.55 | mem size   4105 |
# episode:  85 | score avg: 145.00 | mem size   4281 |
# episode:  86 | score avg: 167.50 | mem size   4651 |
# episode:  87 | score avg: 175.75 | mem size   4901 |
# episode:  88 | score avg: 175.77 | mem size   5077 |
# episode:  89 | score avg: 176.29 | mem size   5258 |
# episode:  90 | score avg: 180.87 | mem size   5480 |
# episode:  91 | score avg: 179.88 | mem size   5651 |
# episode:  92 | score avg: 179.89 | mem size   5831 |
# episode:  93 | score avg: 202.60 | mem size   6238 |
# episode:  94 | score avg: 200.94 | mem size   6424 |
# episode:  95 | score avg: 198.85 | mem size   6604 |
# episode:  96 | score avg: 194.66 | mem size   6761 |
# episode:  97 | score avg: 195.20 | mem size   6961 |
# episode:  98 | score avg: 194.78 | mem size   7152 |
# episode:  99 | score avg: 191.20 | mem size   7311 |
# episode: 100 | score avg: 191.08 | mem size   7501 |
# episode: 101 | score avg: 185.97 | mem size   7641 |
# episode: 102 | score avg: 182.87 | mem size   7796 |
# episode: 103 | score avg: 186.89 | mem size   8019 |
# episode: 104 | score avg: 184.40 | mem size   8181 |
# episode: 105 | score avg: 200.16 | mem size   8523 |
# episode: 106 | score avg: 203.34 | mem size   8755 |
# episode: 107 | score avg: 203.71 | mem size   8962 |
# episode: 108 | score avg: 206.14 | mem size   9190 |
# episode: 109 | score avg: 208.12 | mem size   9416 |
# episode: 110 | score avg: 216.61 | mem size   9709 |
# episode: 111 | score avg: 213.25 | mem size   9892 |
# episode: 112 | score avg: 213.93 | mem size  10000 |
# episode: 113 | score avg: 216.73 | mem size  10000 |
# episode: 114 | score avg: 213.76 | mem size  10000 |
# episode: 115 | score avg: 213.38 | mem size  10000 |
# episode: 116 | score avg: 208.55 | mem size  10000 |
# episode: 117 | score avg: 205.89 | mem size  10000 |
# episode: 118 | score avg: 199.50 | mem size  10000 |
# episode: 119 | score avg: 196.25 | mem size  10000 |
# episode: 120 | score avg: 192.43 | mem size  10000 |
# episode: 121 | score avg: 195.98 | mem size  10000 |
# episode: 122 | score avg: 201.39 | mem size  10000 |
# episode: 123 | score avg: 198.35 | mem size  10000 |
# episode: 124 | score avg: 201.51 | mem size  10000 |
# episode: 125 | score avg: 199.36 | mem size  10000 |
# episode: 126 | score avg: 196.52 | mem size  10000 |
# episode: 127 | score avg: 193.87 | mem size  10000 |
# episode: 128 | score avg: 192.59 | mem size  10000 |
# episode: 129 | score avg: 201.93 | mem size  10000 |
# episode: 130 | score avg: 203.13 | mem size  10000 |
# episode: 131 | score avg: 201.62 | mem size  10000 |
# episode: 132 | score avg: 198.46 | mem size  10000 |
# episode: 133 | score avg: 197.41 | mem size  10000 |
# episode: 134 | score avg: 198.97 | mem size  10000 |
# episode: 135 | score avg: 205.27 | mem size  10000 |
# episode: 136 | score avg: 203.05 | mem size  10000 |
# episode: 137 | score avg: 201.64 | mem size  10000 |
# episode: 138 | score avg: 202.88 | mem size  10000 |
# episode: 139 | score avg: 214.29 | mem size  10000 |
# episode: 140 | score avg: 219.66 | mem size  10000 |
# episode: 141 | score avg: 219.39 | mem size  10000 |
# episode: 142 | score avg: 216.26 | mem size  10000 |
# episode: 143 | score avg: 214.73 | mem size  10000 |
# episode: 144 | score avg: 222.36 | mem size  10000 |
# episode: 145 | score avg: 223.02 | mem size  10000 |
# episode: 146 | score avg: 218.92 | mem size  10000 |
# episode: 147 | score avg: 218.73 | mem size  10000 |
# episode: 148 | score avg: 216.45 | mem size  10000 |
# episode: 149 | score avg: 212.51 | mem size  10000 |
# episode: 150 | score avg: 208.16 | mem size  10000 |
# episode: 151 | score avg: 209.64 | mem size  10000 |
# episode: 152 | score avg: 207.58 | mem size  10000 |
# episode: 153 | score avg: 204.82 | mem size  10000 |
# episode: 154 | score avg: 206.34 | mem size  10000 |
# episode: 155 | score avg: 200.40 | mem size  10000 |
# episode: 156 | score avg: 198.56 | mem size  10000 |
# episode: 157 | score avg: 199.51 | mem size  10000 |
# episode: 158 | score avg: 201.36 | mem size  10000 |
# episode: 159 | score avg: 202.02 | mem size  10000 |
# episode: 160 | score avg: 199.62 | mem size  10000 |
# episode: 161 | score avg: 194.06 | mem size  10000 |
# episode: 162 | score avg: 197.25 | mem size  10000 |
# episode: 163 | score avg: 194.43 | mem size  10000 |
# episode: 164 | score avg: 212.08 | mem size  10000 |
# episode: 165 | score avg: 205.68 | mem size  10000 |
# episode: 166 | score avg: 205.31 | mem size  10000 |
# episode: 167 | score avg: 199.08 | mem size  10000 |
# episode: 168 | score avg: 200.17 | mem size  10000 |
# episode: 169 | score avg: 194.75 | mem size  10000 |
# episode: 170 | score avg: 192.38 | mem size  10000 |
# episode: 171 | score avg: 198.14 | mem size  10000 |
# episode: 172 | score avg: 197.93 | mem size  10000 |
# episode: 173 | score avg: 203.73 | mem size  10000 |
# episode: 174 | score avg: 198.56 | mem size  10000 |
# episode: 175 | score avg: 193.00 | mem size  10000 |
# episode: 176 | score avg: 189.50 | mem size  10000 |
# episode: 177 | score avg: 183.15 | mem size  10000 |
# episode: 178 | score avg: 179.74 | mem size  10000 |
# episode: 179 | score avg: 182.76 | mem size  10000 |
# episode: 180 | score avg: 180.59 | mem size  10000 |
# episode: 181 | score avg: 180.83 | mem size  10000 |
# episode: 182 | score avg: 195.95 | mem size  10000 |
# episode: 183 | score avg: 198.75 | mem size  10000 |
# episode: 184 | score avg: 196.18 | mem size  10000 |
# episode: 185 | score avg: 193.76 | mem size  10000 |
# episode: 186 | score avg: 192.58 | mem size  10000 |
# episode: 187 | score avg: 193.12 | mem size  10000 |
# episode: 188 | score avg: 192.81 | mem size  10000 |
# episode: 189 | score avg: 190.13 | mem size  10000 |
# episode: 190 | score avg: 189.22 | mem size  10000 |
# episode: 191 | score avg: 186.40 | mem size  10000 |
# episode: 192 | score avg: 184.06 | mem size  10000 |
# episode: 193 | score avg: 192.55 | mem size  10000 |
# episode: 194 | score avg: 200.70 | mem size  10000 |
# episode: 195 | score avg: 198.23 | mem size  10000 |
# episode: 196 | score avg: 210.10 | mem size  10000 |
# episode: 197 | score avg: 203.49 | mem size  10000 |
# episode: 198 | score avg: 207.64 | mem size  10000 |
# episode: 199 | score avg: 209.78 | mem size  10000 |
# episode: 200 | score avg: 204.20 | mem size  10000 |
# episode: 201 | score avg: 198.88 | mem size  10000 |
# episode: 202 | score avg: 200.19 | mem size  10000 |
# episode: 203 | score avg: 192.77 | mem size  10000 |
# episode: 204 | score avg: 186.60 | mem size  10000 |
# episode: 205 | score avg: 189.44 | mem size  10000 |
# episode: 206 | score avg: 193.59 | mem size  10000 |
# episode: 207 | score avg: 194.23 | mem size  10000 |
# episode: 208 | score avg: 199.91 | mem size  10000 |
# episode: 209 | score avg: 229.92 | mem size  10000 |
# episode: 210 | score avg: 218.43 | mem size  10000 |
# episode: 211 | score avg: 197.48 | mem size  10000 |
# episode: 212 | score avg: 195.84 | mem size  10000 |
# episode: 213 | score avg: 178.15 | mem size  10000 |
# episode: 214 | score avg: 161.34 | mem size  10000 |
# episode: 215 | score avg: 146.10 | mem size  10000 |
# episode: 216 | score avg: 132.39 | mem size  10000 |
# episode: 217 | score avg: 120.25 | mem size  10000 |
# episode: 218 | score avg: 109.23 | mem size  10000 |
# episode: 219 | score avg: 99.81 | mem size  10000 |
# episode: 220 | score avg: 98.13 | mem size  10000 |
# episode: 221 | score avg: 98.41 | mem size  10000 |
# episode: 222 | score avg: 118.47 | mem size  10000 |
# episode: 223 | score avg: 156.62 | mem size  10000 |
# episode: 224 | score avg: 172.56 | mem size  10000 |
# episode: 225 | score avg: 160.91 | mem size  10000 |
# episode: 226 | score avg: 156.82 | mem size  10000 |
# episode: 227 | score avg: 153.83 | mem size  10000 |
# episode: 228 | score avg: 157.05 | mem size  10000 |
# episode: 229 | score avg: 155.85 | mem size  10000 |
# episode: 230 | score avg: 172.16 | mem size  10000 |
# episode: 231 | score avg: 200.04 | mem size  10000 |
# episode: 232 | score avg: 230.04 | mem size  10000 |
# episode: 233 | score avg: 252.14 | mem size  10000 |
# episode: 234 | score avg: 269.32 | mem size  10000 |
# episode: 235 | score avg: 259.89 | mem size  10000 |
# episode: 236 | score avg: 261.50 | mem size  10000 |
# episode: 237 | score avg: 285.35 | mem size  10000 |
# episode: 238 | score avg: 284.22 | mem size  10000 |
# episode: 239 | score avg: 305.79 | mem size  10000 |
# episode: 240 | score avg: 325.21 | mem size  10000 |
# episode: 241 | score avg: 321.09 | mem size  10000 |
# episode: 242 | score avg: 317.48 | mem size  10000 |
# episode: 243 | score avg: 335.74 | mem size  10000 |
# episode: 244 | score avg: 352.16 | mem size  10000 |
# episode: 245 | score avg: 348.95 | mem size  10000 |
# episode: 246 | score avg: 359.35 | mem size  10000 |
# episode: 247 | score avg: 365.42 | mem size  10000 |
# episode: 248 | score avg: 370.97 | mem size  10000 |
# episode: 249 | score avg: 376.38 | mem size  10000 |
# episode: 250 | score avg: 388.74 | mem size  10000 |
# episode: 251 | score avg: 399.87 | mem size  10000 |
# episode: 252 | score avg: 409.88 | mem size  10000 |
# End
