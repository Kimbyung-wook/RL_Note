# %%
# Find RL_Note path and append sys path
import os, sys
cwd = os.getcwd()
pos = cwd.find('RL_Note')
root_path = cwd[0:pos] + 'RL_Note'
sys.path.append(root_path)
print(root_path)
# Out:
# e:\MyNote\RL_Note

# %%
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from pys.utils.prioritized_memory import ProportionalPrioritizedMemory

# %%
class DQN(tf.keras.Model):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = Dense(24,activation='relu')
        self.fc2 = Dense(24,activation='relu')
        self.out = Dense(action_size,kernel_initializer=tf.keras.initializers.RandomUniform(-1e-3,1e-3))

    def call(self,x):
        x = self.fc1(x)
        x = self.fc2(x)
        q = self.out(x)
        return q

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size= action_size
        
        # Hyper-parameters for learning
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        
        # Experience Replay
        self.batch_size = 32
        self.train_start = 500
        self.buffer_size = 5000
        self.memory = ProportionalPrioritizedMemory(capacity=self.buffer_size)
        
        # Neural Network Architecture
        self.model        = DQN(self.state_size, self.action_size)
        self.target_model = DQN(self.state_size, self.action_size)
        self.optimizer = tf.keras.optimizers.Adam(lr=self.learning_rate)
        
        self.update_target_model()
        
    def remember(self, state, action, reward, next_state, done):
        state = np.reshape(state, [1, self.state_size])
        next_state = np.reshape(next_state, [1, self.state_size])
        transition = (state, action, reward, next_state, done)
        self.memory.append(transition)
        
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())
        
    def choose_action(self,state):
        state = np.reshape(state, [1, self.state_size])
        # Exploration and Exploitation
        if (np.random.rand() <= self.epsilon):
            return random.randrange(self.action_size)
        else:
            return np.argmax(self.model.predict(state))
    
    # def get_td_error(self):

    def train_model(self):
        # Train from Experience Replay
        # Training Condition - Memory Size
        if len(self.memory) < self.train_start:
            return 0.0
        # Decaying Exploration Ratio
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        # Sampling from the memory
        mini_batch, idxs, is_weights = self.memory.sample(self.batch_size)
        
        states      = np.array([sample[0][0] for sample in mini_batch])
        actions     = np.array([sample[1] for sample in mini_batch])
        rewards     = np.array([sample[2] for sample in mini_batch])
        next_states = np.array([sample[3][0] for sample in mini_batch])
        dones       = np.array([sample[4] for sample in mini_batch])
        
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            q = self.model(states)
            one_hot_action = tf.one_hot(actions, self.action_size)
            q = tf.reduce_sum(one_hot_action * q, axis=1)
            
            target_q = tf.stop_gradient(self.target_model(next_states))
            
            max_q = np.amax(target_q, axis=-1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q
            td_error = targets - q
            loss = tf.reduce_mean(is_weights * tf.square(targets - q))
            loss_out = tf.reduce_mean(tf.square(targets - q))
            
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))
        self.update_target_model()
        for i in range(self.batch_size):
            self.memory.update(idxs[i],td_error[i])
        return loss_out

    def save_model(self):
        self.model.save_weights('./save_model/cartpole_dqn_per_TF', save_format='tf')

# %%
# %matplotlib tk

ENV_NAME = 'CartPole-v1'
EPISODES = 1000
END_SCORE = 400

if __name__ == "__main__":
    env = gym.make(ENV_NAME)
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    agent = DQNAgent(state_size, action_size)
    print('Env Name : ',ENV_NAME)
    print('States {}, Actions {}'
            .format(state_size, action_size))

    scores_avg, scores_raw, episodes, losses = [], [], [], []
    epsilons = []
    score_avg = 0
    
    end = False
    
    for e in range(EPISODES):
        # Episode initialization
        done = False
        score = 0
        loss_list = []

        state = env.reset()
        
        while not done:
            #env.render()

            # Interact with env.
            action = agent.choose_action(state)
            next_state, reward, done, info = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            loss = agent.train_model()
            state = next_state

            # 
            score += reward
            loss_list.append(loss)
            if done:
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print('epi: {:3d} | score avg {:3.2f} | mem length: {:4d} | epsilon: {:.4f}'
                      .format(e, score_avg, len(agent.memory), agent.epsilon))

                # Save data for plot
                episodes.append(e)
                scores_avg.append(score_avg)
                scores_raw.append(score)
                losses.append(np.mean(loss_list))
                epsilons.append(agent.epsilon)

                # View data
                plt.clf()
                plt.subplot(311)
                plt.plot(episodes, scores_avg, 'b')
                plt.plot(episodes, scores_raw, 'b', alpha=0.8, linewidth=0.5)
                plt.xlabel('episode'); plt.ylabel('average score'); plt.grid()
                plt.title('LunarLanderv2 DQN PER')
                plt.subplot(312)
                plt.plot(episodes, epsilons, 'b')
                plt.xlabel('episode'); plt.ylabel('epsilon'); plt.grid()
                plt.subplot(313)
                plt.plot(episodes, losses, 'b')
                plt.xlabel('episode'); plt.ylabel('losses') ;plt.grid()
                plt.savefig('./result/cartpole_dqn_per_TF.png')

                if score_avg > END_SCORE:
                    agent.save_model()
                    end = True
                    break
        if end == True:
            env.close()
            np.save('./save_model/data/cartpole_dqn_per_TF_epi',  episodes)
            np.save('./save_model/data/cartpole_dqn_per_TF_scores_avg',scores_avg)
            np.save('./save_model/data/cartpole_dqn_per_TF_scores_raw',scores_raw)
            np.save('./save_model/data/cartpole_dqn_per_TF_loss', losses)
            print("End")
            break
# Out:
# em length: 10000 | epsilon: 0.0100
# epi: 272 | score avg 55.30 | mem length: 10000 | epsilon: 0.0100
# epi: 273 | score avg 50.67 | mem length: 10000 | epsilon: 0.0100
# epi: 274 | score avg 46.50 | mem length: 10000 | epsilon: 0.0100
# epi: 275 | score avg 42.85 | mem length: 10000 | epsilon: 0.0100
# epi: 276 | score avg 39.47 | mem length: 10000 | epsilon: 0.0100
# epi: 277 | score avg 36.52 | mem length: 10000 | epsilon: 0.0100
# epi: 278 | score avg 33.87 | mem length: 10000 | epsilon: 0.0100
# epi: 279 | score avg 31.38 | mem length: 10000 | epsilon: 0.0100
# epi: 280 | score avg 29.04 | mem length: 10000 | epsilon: 0.0100
# epi: 281 | score avg 27.04 | mem length: 10000 | epsilon: 0.0100
# epi: 282 | score avg 25.23 | mem length: 10000 | epsilon: 0.0100
# epi: 283 | score avg 23.61 | mem length: 10000 | epsilon: 0.0100
# epi: 284 | score avg 22.15 | mem length: 10000 | epsilon: 0.0100
# epi: 285 | score avg 20.83 | mem length: 10000 | epsilon: 0.0100
# epi: 286 | score avg 19.75 | mem length: 10000 | epsilon: 0.0100
# epi: 287 | score avg 19.18 | mem length: 10000 | epsilon: 0.0100
# epi: 288 | score avg 18.86 | mem length: 10000 | epsilon: 0.0100
# epi: 289 | score avg 22.07 | mem length: 10000 | epsilon: 0.0100
# epi: 290 | score avg 27.37 | mem length: 10000 | epsilon: 0.0100
# epi: 291 | score avg 41.33 | mem length: 10000 | epsilon: 0.0100
# epi: 292 | score avg 40.90 | mem length: 10000 | epsilon: 0.0100
# epi: 293 | score avg 40.51 | mem length: 10000 | epsilon: 0.0100
# epi: 294 | score avg 39.26 | mem length: 10000 | epsilon: 0.0100
# epi: 295 | score avg 38.53 | mem length: 10000 | epsilon: 0.0100
# epi: 296 | score avg 38.08 | mem length: 10000 | epsilon: 0.0100
# epi: 297 | score avg 39.47 | mem length: 10000 | epsilon: 0.0100
# epi: 298 | score avg 38.32 | mem length: 10000 | epsilon: 0.0100
# epi: 299 | score avg 37.69 | mem length: 10000 | epsilon: 0.0100
# epi: 300 | score avg 36.82 | mem length: 10000 | epsilon: 0.0100
# epi: 301 | score avg 36.04 | mem length: 10000 | epsilon: 0.0100
# epi: 302 | score avg 36.44 | mem length: 10000 | epsilon: 0.0100
# epi: 303 | score avg 35.09 | mem length: 10000 | epsilon: 0.0100
# epi: 304 | score avg 34.28 | mem length: 10000 | epsilon: 0.0100
# epi: 305 | score avg 34.45 | mem length: 10000 | epsilon: 0.0100
# epi: 306 | score avg 34.91 | mem length: 10000 | epsilon: 0.0100
# epi: 307 | score avg 34.62 | mem length: 10000 | epsilon: 0.0100
# epi: 308 | score avg 35.26 | mem length: 10000 | epsilon: 0.0100
# epi: 309 | score avg 36.23 | mem length: 10000 | epsilon: 0.0100
# epi: 310 | score avg 36.51 | mem length: 10000 | epsilon: 0.0100
# epi: 311 | score avg 36.86 | mem length: 10000 | epsilon: 0.0100
# epi: 312 | score avg 35.77 | mem length: 10000 | epsilon: 0.0100
# epi: 313 | score avg 34.79 | mem length: 10000 | epsilon: 0.0100
# epi: 314 | score avg 35.51 | mem length: 10000 | epsilon: 0.0100
# epi: 315 | score avg 35.36 | mem length: 10000 | epsilon: 0.0100
# epi: 316 | score avg 34.83 | mem length: 10000 | epsilon: 0.0100
# epi: 317 | score avg 34.94 | mem length: 10000 | epsilon: 0.0100
# epi: 318 | score avg 34.15 | mem length: 10000 | epsilon: 0.0100
# epi: 319 | score avg 33.73 | mem length: 10000 | epsilon: 0.0100
# epi: 320 | score avg 33.46 | mem length: 10000 | epsilon: 0.0100
# epi: 321 | score avg 34.12 | mem length: 10000 | epsilon: 0.0100
# epi: 322 | score avg 34.40 | mem length: 10000 | epsilon: 0.0100
# epi: 323 | score avg 34.76 | mem length: 10000 | epsilon: 0.0100
# epi: 324 | score avg 36.29 | mem length: 10000 | epsilon: 0.0100
# epi: 325 | score avg 36.06 | mem length: 10000 | epsilon: 0.0100
# epi: 326 | score avg 36.65 | mem length: 10000 | epsilon: 0.0100
# epi: 327 | score avg 37.79 | mem length: 10000 | epsilon: 0.0100
# epi: 328 | score avg 39.21 | mem length: 10000 | epsilon: 0.0100
# epi: 329 | score avg 40.49 | mem length: 10000 | epsilon: 0.0100
# epi: 330 | score avg 42.54 | mem length: 10000 | epsilon: 0.0100
# epi: 331 | score avg 42.18 | mem length: 10000 | epsilon: 0.0100
# epi: 332 | score avg 44.07 | mem length: 10000 | epsilon: 0.0100
# epi: 333 | score avg 44.66 | mem length: 10000 | epsilon: 0.0100
# epi: 334 | score avg 45.79 | mem length: 10000 | epsilon: 0.0100
# epi: 335 | score avg 48.11 | mem length: 10000 | epsilon: 0.0100
# epi: 336 | score avg 49.40 | mem length: 10000 | epsilon: 0.0100
# epi: 337 | score avg 50.36 | mem length: 10000 | epsilon: 0.0100
# epi: 338 | score avg 51.83 | mem length: 10000 | epsilon: 0.0100
# epi: 339 | score avg 56.74 | mem length: 10000 | epsilon: 0.0100
# epi: 340 | score avg 63.67 | mem length: 10000 | epsilon: 0.0100
# epi: 341 | score avg 67.10 | mem length: 10000 | epsilon: 0.0100
# epi: 342 | score avg 71.89 | mem length: 10000 | epsilon: 0.0100
# epi: 343 | score avg 73.10 | mem length: 10000 | epsilon: 0.0100
# epi: 344 | score avg 77.09 | mem length: 10000 | epsilon: 0.0100
# epi: 345 | score avg 75.78 | mem length: 10000 | epsilon: 0.0100
# epi: 346 | score avg 79.61 | mem length: 10000 | epsilon: 0.0100
# epi: 347 | score avg 93.64 | mem length: 10000 | epsilon: 0.0100
# epi: 348 | score avg 105.68 | mem length: 10000 | epsilon: 0.0100
# epi: 349 | score avg 120.71 | mem length: 10000 | epsilon: 0.0100
# epi: 350 | score avg 131.94 | mem length: 10000 | epsilon: 0.0100
# epi: 351 | score avg 141.65 | mem length: 10000 | epsilon: 0.0100
# epi: 352 | score avg 154.38 | mem length: 10000 | epsilon: 0.0100
# epi: 353 | score avg 165.54 | mem length: 10000 | epsilon: 0.0100
# epi: 354 | score avg 180.19 | mem length: 10000 | epsilon: 0.0100
# epi: 355 | score avg 191.77 | mem length: 10000 | epsilon: 0.0100
# epi: 356 | score avg 196.79 | mem length: 10000 | epsilon: 0.0100
# epi: 357 | score avg 200.91 | mem length: 10000 | epsilon: 0.0100
# epi: 358 | score avg 207.02 | mem length: 10000 | epsilon: 0.0100
# epi: 359 | score avg 210.32 | mem length: 10000 | epsilon: 0.0100
# epi: 360 | score avg 216.19 | mem length: 10000 | epsilon: 0.0100
# epi: 361 | score avg 216.57 | mem length: 10000 | epsilon: 0.0100
# epi: 362 | score avg 216.31 | mem length: 10000 | epsilon: 0.0100
# epi: 363 | score avg 217.68 | mem length: 10000 | epsilon: 0.0100
# epi: 364 | score avg 224.41 | mem length: 10000 | epsilon: 0.0100
# epi: 365 | score avg 228.37 | mem length: 10000 | epsilon: 0.0100
# epi: 366 | score avg 230.13 | mem length: 10000 | epsilon: 0.0100
# epi: 367 | score avg 245.02 | mem length: 10000 | epsilon: 0.0100
# epi: 368 | score avg 261.52 | mem length: 10000 | epsilon: 0.0100
# epi: 369 | score avg 265.67 | mem length: 10000 | epsilon: 0.0100
# epi: 370 | score avg 284.80 | mem length: 10000 | epsilon: 0.0100
# epi: 371 | score avg 290.62 | mem length: 10000 | epsilon: 0.0100
# epi: 372 | score avg 288.86 | mem length: 10000 | epsilon: 0.0100
# epi: 373 | score avg 276.77 | mem length: 10000 | epsilon: 0.0100
# epi: 374 | score avg 270.50 | mem length: 10000 | epsilon: 0.0100
# epi: 375 | score avg 261.75 | mem length: 10000 | epsilon: 0.0100
# epi: 376 | score avg 250.17 | mem length: 10000 | epsilon: 0.0100
# epi: 377 | score avg 237.25 | mem length: 10000 | epsilon: 0.0100
# epi: 378 | score avg 229.93 | mem length: 10000 | epsilon: 0.0100
# epi: 379 | score avg 222.34 | mem length: 10000 | epsilon: 0.0100
# epi: 380 | score avg 212.10 | mem length: 10000 | epsilon: 0.0100
# epi: 381 | score avg 209.49 | mem length: 10000 | epsilon: 0.0100
# epi: 382 | score avg 204.54 | mem length: 10000 | epsilon: 0.0100
# epi: 383 | score avg 216.09 | mem length: 10000 | epsilon: 0.0100
# epi: 384 | score avg 228.78 | mem length: 10000 | epsilon: 0.0100
# epi: 385 | score avg 234.60 | mem length: 10000 | epsilon: 0.0100
# epi: 386 | score avg 252.04 | mem length: 10000 | epsilon: 0.0100
# epi: 387 | score avg 264.34 | mem length: 10000 | epsilon: 0.0100
# epi: 388 | score avg 276.30 | mem length: 10000 | epsilon: 0.0100
# epi: 389 | score avg 296.47 | mem length: 10000 | epsilon: 0.0100
# epi: 390 | score avg 284.53 | mem length: 10000 | epsilon: 0.0100
# epi: 391 | score avg 269.47 | mem length: 10000 | epsilon: 0.0100
# epi: 392 | score avg 274.73 | mem length: 10000 | epsilon: 0.0100
# epi: 393 | score avg 284.65 | mem length: 10000 | epsilon: 0.0100
# epi: 394 | score avg 306.19 | mem length: 10000 | epsilon: 0.0100
# epi: 395 | score avg 282.37 | mem length: 10000 | epsilon: 0.0100
# epi: 396 | score avg 255.13 | mem length: 10000 | epsilon: 0.0100
# epi: 397 | score avg 230.62 | mem length: 10000 | epsilon: 0.0100
# epi: 398 | score avg 208.46 | mem length: 10000 | epsilon: 0.0100
# epi: 399 | score avg 188.51 | mem length: 10000 | epsilon: 0.0100
# epi: 400 | score avg 170.46 | mem length: 10000 | epsilon: 0.0100
# epi: 401 | score avg 154.41 | mem length: 10000 | epsilon: 0.0100
# epi: 402 | score avg 139.97 | mem length: 10000 | epsilon: 0.0100
# epi: 403 | score avg 126.98 | mem length: 10000 | epsilon: 0.0100
# epi: 404 | score avg 115.28 | mem length: 10000 | epsilon: 0.0100
# epi: 405 | score avg 104.65 | mem length: 10000 | epsilon: 0.0100
# epi: 406 | score avg 95.09 | mem length: 10000 | epsilon: 0.0100
# epi: 407 | score avg 86.38 | mem length: 10000 | epsilon: 0.0100
# epi: 408 | score avg 78.54 | mem length: 10000 | epsilon: 0.0100
# epi: 409 | score avg 71.59 | mem length: 10000 | epsilon: 0.0100
# epi: 410 | score avg 65.43 | mem length: 10000 | epsilon: 0.0100
# epi: 411 | score avg 59.78 | mem length: 10000 | epsilon: 0.0100
# epi: 412 | score avg 54.81 | mem length: 10000 | epsilon: 0.0100
# epi: 413 | score avg 50.22 | mem length: 10000 | epsilon: 0.0100
# epi: 414 | score avg 46.10 | mem length: 10000 | epsilon: 0.0100
# epi: 415 | score avg 42.39 | mem length: 10000 | epsilon: 0.0100
# epi: 416 | score avg 39.15 | mem length: 10000 | epsilon: 0.0100
# epi: 417 | score avg 36.14 | mem length: 10000 | epsilon: 0.0100
# epi: 418 | score avg 33.42 | mem length: 10000 | epsilon: 0.0100
# epi: 419 | score avg 31.18 | mem length: 10000 | epsilon: 0.0100
# epi: 420 | score avg 29.06 | mem length: 10000 | epsilon: 0.0100
# epi: 421 | score avg 27.26 | mem length: 10000 | epsilon: 0.0100
# epi: 422 | score avg 25.73 | mem length: 10000 | epsilon: 0.0100
# epi: 423 | score avg 24.26 | mem length: 10000 | epsilon: 0.0100
# epi: 424 | score avg 23.03 | mem length: 10000 | epsilon: 0.0100
# epi: 425 | score avg 22.03 | mem length: 10000 | epsilon: 0.0100
# epi: 426 | score avg 21.03 | mem length: 10000 | epsilon: 0.0100
# epi: 427 | score avg 20.52 | mem length: 10000 | epsilon: 0.0100
# epi: 428 | score avg 20.27 | mem length: 10000 | epsilon: 0.0100
# epi: 429 | score avg 24.34 | mem length: 10000 | epsilon: 0.0100
# epi: 430 | score avg 29.01 | mem length: 10000 | epsilon: 0.0100
# epi: 431 | score avg 36.21 | mem length: 10000 | epsilon: 0.0100
# epi: 432 | score avg 69.09 | mem length: 10000 | epsilon: 0.0100
# epi: 433 | score avg 77.08 | mem length: 10000 | epsilon: 0.0100
# epi: 434 | score avg 82.77 | mem length: 10000 | epsilon: 0.0100
# epi: 435 | score avg 87.59 | mem length: 10000 | epsilon: 0.0100
# epi: 436 | score avg 92.53 | mem length: 10000 | epsilon: 0.0100
# epi: 437 | score avg 95.58 | mem length: 10000 | epsilon: 0.0100
# epi: 438 | score avg 98.42 | mem length: 10000 | epsilon: 0.0100
# epi: 439 | score avg 100.38 | mem length: 10000 | epsilon: 0.0100
# epi: 440 | score avg 102.44 | mem length: 10000 | epsilon: 0.0100
# epi: 441 | score avg 103.20 | mem length: 10000 | epsilon: 0.0100
# epi: 442 | score avg 104.28 | mem length: 10000 | epsilon: 0.0100
# epi: 443 | score avg 105.05 | mem length: 10000 | epsilon: 0.0100
# epi: 444 | score avg 104.75 | mem length: 10000 | epsilon: 0.0100
# epi: 445 | score avg 105.67 | mem length: 10000 | epsilon: 0.0100
# epi: 446 | score avg 106.30 | mem length: 10000 | epsilon: 0.0100
# epi: 447 | score avg 106.17 | mem length: 10000 | epsilon: 0.0100
# epi: 448 | score avg 105.46 | mem length: 10000 | epsilon: 0.0100
# epi: 449 | score avg 104.61 | mem length: 10000 | epsilon: 0.0100
# epi: 450 | score avg 97.05 | mem length: 10000 | epsilon: 0.0100
# epi: 451 | score avg 90.84 | mem length: 10000 | epsilon: 0.0100
# epi: 452 | score avg 84.26 | mem length: 10000 | epsilon: 0.0100
# epi: 453 | score avg 78.03 | mem length: 10000 | epsilon: 0.0100
# epi: 454 | score avg 73.63 | mem length: 10000 | epsilon: 0.0100
# epi: 455 | score avg 68.27 | mem length: 10000 | epsilon: 0.0100
# epi: 456 | score avg 63.44 | mem length: 10000 | epsilon: 0.0100
# epi: 457 | score avg 58.90 | mem length: 10000 | epsilon: 0.0100
# epi: 458 | score avg 55.91 | mem length: 10000 | epsilon: 0.0100
# epi: 459 | score avg 52.52 | mem length: 10000 | epsilon: 0.0100
# epi: 460 | score avg 49.76 | mem length: 10000 | epsilon: 0.0100
# epi: 461 | score avg 55.09 | mem length: 10000 | epsilon: 0.0100
# epi: 462 | score avg 60.48 | mem length: 10000 | epsilon: 0.0100
# epi: 463 | score avg 65.83 | mem length: 10000 | epsilon: 0.0100
# epi: 464 | score avg 72.05 | mem length: 10000 | epsilon: 0.0100
# epi: 465 | score avg 77.84 | mem length: 10000 | epsilon: 0.0100
# epi: 466 | score avg 86.46 | mem length: 10000 | epsilon: 0.0100
# epi: 467 | score avg 94.21 | mem length: 10000 | epsilon: 0.0100
# epi: 468 | score avg 101.79 | mem length: 10000 | epsilon: 0.0100
# epi: 469 | score avg 108.31 | mem length: 10000 | epsilon: 0.0100
# epi: 470 | score avg 116.28 | mem length: 10000 | epsilon: 0.0100
# epi: 471 | score avg 125.05 | mem length: 10000 | epsilon: 0.0100
# epi: 472 | score avg 133.65 | mem length: 10000 | epsilon: 0.0100
# epi: 473 | score avg 148.18 | mem length: 10000 | epsilon: 0.0100
# epi: 474 | score avg 158.76 | mem length: 10000 | epsilon: 0.0100
# epi: 475 | score avg 187.79 | mem length: 10000 | epsilon: 0.0100
# epi: 476 | score avg 219.01 | mem length: 10000 | epsilon: 0.0100
# epi: 477 | score avg 247.11 | mem length: 10000 | epsilon: 0.0100
# epi: 478 | score avg 238.80 | mem length: 10000 | epsilon: 0.0100
# epi: 479 | score avg 230.72 | mem length: 10000 | epsilon: 0.0100
# epi: 480 | score avg 223.95 | mem length: 10000 | epsilon: 0.0100
# epi: 481 | score avg 230.85 | mem length: 10000 | epsilon: 0.0100
# epi: 482 | score avg 229.57 | mem length: 10000 | epsilon: 0.0100
# epi: 483 | score avg 224.71 | mem length: 10000 | epsilon: 0.0100
# epi: 484 | score avg 221.04 | mem length: 10000 | epsilon: 0.0100
# epi: 485 | score avg 220.43 | mem length: 10000 | epsilon: 0.0100
# epi: 486 | score avg 221.69 | mem length: 10000 | epsilon: 0.0100
# epi: 487 | score avg 233.82 | mem length: 10000 | epsilon: 0.0100
# epi: 488 | score avg 260.44 | mem length: 10000 | epsilon: 0.0100
# epi: 489 | score avg 254.60 | mem length: 10000 | epsilon: 0.0100
# epi: 490 | score avg 279.04 | mem length: 10000 | epsilon: 0.0100
# epi: 491 | score avg 271.03 | mem length: 10000 | epsilon: 0.0100
# epi: 492 | score avg 258.33 | mem length: 10000 | epsilon: 0.0100
# epi: 493 | score avg 242.80 | mem length: 10000 | epsilon: 0.0100
# epi: 494 | score avg 225.82 | mem length: 10000 | epsilon: 0.0100
# epi: 495 | score avg 204.34 | mem length: 10000 | epsilon: 0.0100
# epi: 496 | score avg 184.90 | mem length: 10000 | epsilon: 0.0100
# epi: 497 | score avg 167.41 | mem length: 10000 | epsilon: 0.0100
# epi: 498 | score avg 151.67 | mem length: 10000 | epsilon: 0.0100
# epi: 499 | score avg 137.60 | mem length: 10000 | epsilon: 0.0100
# epi: 500 | score avg 124.74 | mem length: 10000 | epsilon: 0.0100
# epi: 501 | score avg 113.17 | mem length: 10000 | epsilon: 0.0100
# epi: 502 | score avg 102.85 | mem length: 10000 | epsilon: 0.0100
# epi: 503 | score avg 93.67 | mem length: 10000 | epsilon: 0.0100
# epi: 504 | score avg 85.20 | mem length: 10000 | epsilon: 0.0100
# epi: 505 | score avg 77.48 | mem length: 10000 | epsilon: 0.0100
# epi: 506 | score avg 70.73 | mem length: 10000 | epsilon: 0.0100
# epi: 507 | score avg 64.66 | mem length: 10000 | epsilon: 0.0100
# epi: 508 | score avg 58.99 | mem length: 10000 | epsilon: 0.0100
# epi: 509 | score avg 54.09 | mem length: 10000 | epsilon: 0.0100
# epi: 510 | score avg 49.58 | mem length: 10000 | epsilon: 0.0100
# epi: 511 | score avg 45.53 | mem length: 10000 | epsilon: 0.0100
# epi: 512 | score avg 41.97 | mem length: 10000 | epsilon: 0.0100
# epi: 513 | score avg 38.68 | mem length: 10000 | epsilon: 0.0100
# epi: 514 | score avg 35.81 | mem length: 10000 | epsilon: 0.0100
# epi: 515 | score avg 33.23 | mem length: 10000 | epsilon: 0.0100
# epi: 516 | score avg 30.70 | mem length: 10000 | epsilon: 0.0100
# epi: 517 | score avg 28.53 | mem length: 10000 | epsilon: 0.0100
# epi: 518 | score avg 26.68 | mem length: 10000 | epsilon: 0.0100
# epi: 519 | score avg 24.91 | mem length: 10000 | epsilon: 0.0100
# epi: 520 | score avg 23.32 | mem length: 10000 | epsilon: 0.0100
# epi: 521 | score avg 21.99 | mem length: 10000 | epsilon: 0.0100
# epi: 522 | score avg 20.79 | mem length: 10000 | epsilon: 0.0100
# epi: 523 | score avg 19.81 | mem length: 10000 | epsilon: 0.0100
# epi: 524 | score avg 19.03 | mem length: 10000 | epsilon: 0.0100
# epi: 525 | score avg 18.23 | mem length: 10000 | epsilon: 0.0100
# epi: 526 | score avg 17.50 | mem length: 10000 | epsilon: 0.0100
# epi: 527 | score avg 16.75 | mem length: 10000 | epsilon: 0.0100
# epi: 528 | score avg 16.28 | mem length: 10000 | epsilon: 0.0100
# epi: 529 | score avg 15.75 | mem length: 10000 | epsilon: 0.0100
# epi: 530 | score avg 15.38 | mem length: 10000 | epsilon: 0.0100
# epi: 531 | score avg 14.94 | mem length: 10000 | epsilon: 0.0100
# epi: 532 | score avg 14.44 | mem length: 10000 | epsilon: 0.0100
# epi: 533 | score avg 14.10 | mem length: 10000 | epsilon: 0.0100
# epi: 534 | score avg 13.99 | mem length: 10000 | epsilon: 0.0100
# epi: 535 | score avg 13.79 | mem length: 10000 | epsilon: 0.0100
# epi: 536 | score avg 13.81 | mem length: 10000 | epsilon: 0.0100
# epi: 537 | score avg 14.13 | mem length: 10000 | epsilon: 0.0100
# epi: 538 | score avg 14.32 | mem length: 10000 | epsilon: 0.0100
# epi: 539 | score avg 14.89 | mem length: 10000 | epsilon: 0.0100
# epi: 540 | score avg 20.10 | mem length: 10000 | epsilon: 0.0100
# epi: 541 | score avg 27.09 | mem length: 10000 | epsilon: 0.0100
# epi: 542 | score avg 34.48 | mem length: 10000 | epsilon: 0.0100
# epi: 543 | score avg 44.73 | mem length: 10000 | epsilon: 0.0100
# epi: 544 | score avg 90.26 | mem length: 10000 | epsilon: 0.0100
# epi: 545 | score avg 118.43 | mem length: 10000 | epsilon: 0.0100
# epi: 546 | score avg 143.69 | mem length: 10000 | epsilon: 0.0100
# epi: 547 | score avg 155.42 | mem length: 10000 | epsilon: 0.0100
# epi: 548 | score avg 161.08 | mem length: 10000 | epsilon: 0.0100
# epi: 549 | score avg 163.77 | mem length: 10000 | epsilon: 0.0100
# epi: 550 | score avg 163.79 | mem length: 10000 | epsilon: 0.0100
# epi: 551 | score avg 164.31 | mem length: 10000 | epsilon: 0.0100
# epi: 552 | score avg 164.38 | mem length: 10000 | epsilon: 0.0100
# epi: 553 | score avg 163.34 | mem length: 10000 | epsilon: 0.0100
# epi: 554 | score avg 161.11 | mem length: 10000 | epsilon: 0.0100
# epi: 555 | score avg 160.50 | mem length: 10000 | epsilon: 0.0100
# epi: 556 | score avg 160.95 | mem length: 10000 | epsilon: 0.0100
# epi: 557 | score avg 160.95 | mem length: 10000 | epsilon: 0.0100
# epi: 558 | score avg 161.46 | mem length: 10000 | epsilon: 0.0100
# epi: 559 | score avg 161.21 | mem length: 10000 | epsilon: 0.0100
# epi: 560 | score avg 161.39 | mem length: 10000 | epsilon: 0.0100
# epi: 561 | score avg 163.45 | mem length: 10000 | epsilon: 0.0100
# epi: 562 | score avg 166.01 | mem length: 10000 | epsilon: 0.0100
# epi: 563 | score avg 172.41 | mem length: 10000 | epsilon: 0.0100
# epi: 564 | score avg 179.77 | mem length: 10000 | epsilon: 0.0100
# epi: 565 | score avg 211.79 | mem length: 10000 | epsilon: 0.0100
# epi: 566 | score avg 240.61 | mem length: 10000 | epsilon: 0.0100
# epi: 567 | score avg 266.55 | mem length: 10000 | epsilon: 0.0100
# epi: 568 | score avg 289.89 | mem length: 10000 | epsilon: 0.0100
# epi: 569 | score avg 310.90 | mem length: 10000 | epsilon: 0.0100
# epi: 570 | score avg 329.81 | mem length: 10000 | epsilon: 0.0100
# epi: 571 | score avg 346.83 | mem length: 10000 | epsilon: 0.0100
# epi: 572 | score avg 362.15 | mem length: 10000 | epsilon: 0.0100
# epi: 573 | score avg 375.93 | mem length: 10000 | epsilon: 0.0100
# epi: 574 | score avg 388.34 | mem length: 10000 | epsilon: 0.0100
# epi: 575 | score avg 399.51 | mem length: 10000 | epsilon: 0.0100
# epi: 576 | score avg 409.56 | mem length: 10000 | epsilon: 0.0100
# End
