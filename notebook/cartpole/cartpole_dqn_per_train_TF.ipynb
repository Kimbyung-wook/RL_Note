# %%
# Find RL_Note path and append sys path
import os, sys
cwd = os.getcwd()
pos = cwd.find('RL_Note')
root_path = cwd[0:pos] + 'RL_Note'
sys.path.append(root_path)
print(root_path)
# Out:
# e:\MyNote\RL_Note

# %%
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from pys.utils.prioritized_memory import ProportionalPrioritizedMemory

# %%
class DQN(tf.keras.Model):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = Dense(255,activation='relu')
        self.fc2 = Dense(255,activation='relu')
        self.out = Dense(action_size,kernel_initializer=tf.keras.initializers.RandomUniform(-1e-3,1e-3))

    def call(self,x):
        x = self.fc1(x)
        x = self.fc2(x)
        q = self.out(x)
        return q

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size= action_size
        
        # Hyper-parameters for learning
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        
        # Experience Replay
        self.batch_size = 8
        self.train_start = 500
        self.buffer_size = 10000
        self.memory = ProportionalPrioritizedMemory(capacity=self.buffer_size)
        
        # Neural Network Architecture
        self.model        = DQN(self.state_size, self.action_size)
        self.target_model = DQN(self.state_size, self.action_size)
        self.optimizer = tf.keras.optimizers.Adam(lr=self.learning_rate)
        
        self.update_target_model()
        self.show_media_info = False
        
    def remember(self, state, action, reward, next_state, done):
        state = np.reshape(state, [1, self.state_size])
        next_state = np.reshape(next_state, [1, self.state_size])
        transition = (state, action, reward, next_state, done)
        self.memory.append(transition)
        
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())
        
    def choose_action(self,state):
        state = np.reshape(state, [1, self.state_size])
        # Exploration and Exploitation
        if (np.random.rand() <= self.epsilon):
            return random.randrange(self.action_size)
        else:
            return np.argmax(self.model.predict(state))
    
    # def get_td_error(self):

    def train_model(self):
        # Train from Experience Replay
        # Training Condition - Memory Size
        if len(self.memory) < self.train_start:
            return 0.0
        # Decaying Exploration Ratio
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        # Sampling from the memory
        mini_batch, idxs, is_weights = self.memory.sample(self.batch_size)
        
        states      = tf.convert_to_tensor(np.array([sample[0][0] for sample in mini_batch]))
        actions     = tf.convert_to_tensor(np.array([sample[1] for sample in mini_batch]))
        rewards     = tf.convert_to_tensor(np.array([sample[2] for sample in mini_batch]),dtype=tf.float32)
        rewards     = tf.expand_dims(rewards, axis = 1)
        next_states = tf.convert_to_tensor(np.array([sample[3][0] for sample in mini_batch]))
        dones       = tf.convert_to_tensor(np.array([sample[4] for sample in mini_batch]),dtype=tf.float32)
        dones       = tf.expand_dims(dones, axis = 1)
        
        if self.show_media_info == False:
            self.show_media_info = True
            print('Start to train, check batch shapes')
            print('shape of states', np.shape(states),type(states))
            print('shape of actions', np.shape(actions),type(actions))
            print('shape of rewards', np.shape(rewards),type(rewards))
            print('shape of next_states', np.shape(next_states),type(next_states))
            print('shape of dones', np.shape(dones),type(dones))
            
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            q = self.model(states)
            one_hot_action = tf.one_hot(actions, self.action_size)
            q = tf.reduce_sum(one_hot_action * q, axis=1)
            q = tf.expand_dims(q,axis=1)
            
            target_q = tf.stop_gradient(self.target_model(next_states))
            max_q = tf.reduce_max(target_q,axis=1)
            max_q = tf.expand_dims(max_q,axis=1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q
            td_error = targets - q
            loss = tf.reduce_mean(is_weights * tf.square(targets - q))
            loss_out = tf.reduce_mean(tf.square(targets - q))
            
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))
        self.update_target_model()
        for i in range(self.batch_size):
            self.memory.update(idxs[i],td_error[i])
        return loss_out

    def save_model(self):
        self.model.save_weights('./save_model/cartpole_dqn_per_TF', save_format='tf')

# %%
# %matplotlib tk

ENV_NAME = 'CartPole-v1'
EPISODES = 1000
END_SCORE = 400

if __name__ == "__main__":
    env = gym.make(ENV_NAME)
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    agent = DQNAgent(state_size, action_size)
    print('Env Name : ',ENV_NAME)
    print('States {}, Actions {}'
            .format(state_size, action_size))

    scores_avg, scores_raw, episodes, losses = [], [], [], []
    epsilons = []
    score_avg = 0
    
    end = False
    
    for e in range(EPISODES):
        # Episode initialization
        done = False
        score = 0
        loss_list = []

        state = env.reset()
        
        while not done:
            #env.render()

            # Interact with env.
            action = agent.choose_action(state)
            next_state, reward, done, info = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            loss = agent.train_model()
            state = next_state

            # 
            score += reward
            loss_list.append(loss)
            if done:
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print('epi: {:3d} | score avg {:3.2f} | mem length: {:4d} | epsilon: {:.4f}'
                      .format(e, score_avg, len(agent.memory), agent.epsilon))

                # Save data for plot
                episodes.append(e)
                scores_avg.append(score_avg)
                scores_raw.append(score)
                losses.append(np.mean(loss_list))
                epsilons.append(agent.epsilon)

                # View data
                plt.clf()
                plt.subplot(311)
                plt.plot(episodes, scores_avg, 'b')
                plt.plot(episodes, scores_raw, 'b', alpha=0.8, linewidth=0.5)
                plt.xlabel('episode'); plt.ylabel('average score'); plt.grid()
                plt.title('LunarLanderv2 DQN PER')
                plt.subplot(312)
                plt.plot(episodes, epsilons, 'b')
                plt.xlabel('episode'); plt.ylabel('epsilon'); plt.grid()
                plt.subplot(313)
                plt.plot(episodes, losses, 'b')
                plt.xlabel('episode'); plt.ylabel('losses') ;plt.grid()
                plt.savefig('./result/N255_B8/cartpole_dqn_per_TF.png')

                if score_avg > END_SCORE:
                    agent.save_model()
                    end = True
                    break
        if end == True:
            env.close()
            np.save('./result/N255_B8/cartpole_dqn_per_TF_epi',  episodes)
            np.save('./result/N255_B8/cartpole_dqn_per_TF_scores_avg',scores_avg)
            np.save('./result/N255_B8/cartpole_dqn_per_TF_scores_raw',scores_raw)
            np.save('./result/N255_B8/cartpole_dqn_per_TF_loss', losses)
            print("End")
            break
# Out:
# ength: 10000 | epsilon: 0.0100
# epi: 265 | score avg 100.21 | mem length: 10000 | epsilon: 0.0100
# epi: 266 | score avg 101.09 | mem length: 10000 | epsilon: 0.0100
# epi: 267 | score avg 100.88 | mem length: 10000 | epsilon: 0.0100
# epi: 268 | score avg 100.00 | mem length: 10000 | epsilon: 0.0100
# epi: 269 | score avg 99.50 | mem length: 10000 | epsilon: 0.0100
# epi: 270 | score avg 99.45 | mem length: 10000 | epsilon: 0.0100
# epi: 271 | score avg 101.30 | mem length: 10000 | epsilon: 0.0100
# epi: 272 | score avg 141.17 | mem length: 10000 | epsilon: 0.0100
# epi: 273 | score avg 166.55 | mem length: 10000 | epsilon: 0.0100
# epi: 274 | score avg 183.60 | mem length: 10000 | epsilon: 0.0100
# epi: 275 | score avg 211.44 | mem length: 10000 | epsilon: 0.0100
# epi: 276 | score avg 240.29 | mem length: 10000 | epsilon: 0.0100
# epi: 277 | score avg 266.27 | mem length: 10000 | epsilon: 0.0100
# epi: 278 | score avg 289.64 | mem length: 10000 | epsilon: 0.0100
# epi: 279 | score avg 310.68 | mem length: 10000 | epsilon: 0.0100
# epi: 280 | score avg 329.61 | mem length: 10000 | epsilon: 0.0100
# epi: 281 | score avg 346.65 | mem length: 10000 | epsilon: 0.0100
# epi: 282 | score avg 361.98 | mem length: 10000 | epsilon: 0.0100
# epi: 283 | score avg 375.78 | mem length: 10000 | epsilon: 0.0100
# epi: 284 | score avg 358.81 | mem length: 10000 | epsilon: 0.0100
# epi: 285 | score avg 335.72 | mem length: 10000 | epsilon: 0.0100
# epi: 286 | score avg 313.05 | mem length: 10000 | epsilon: 0.0100
# epi: 287 | score avg 296.95 | mem length: 10000 | epsilon: 0.0100
# epi: 288 | score avg 293.75 | mem length: 10000 | epsilon: 0.0100
# epi: 289 | score avg 314.38 | mem length: 10000 | epsilon: 0.0100
# epi: 290 | score avg 332.94 | mem length: 10000 | epsilon: 0.0100
# epi: 291 | score avg 312.45 | mem length: 10000 | epsilon: 0.0100
# epi: 292 | score avg 300.30 | mem length: 10000 | epsilon: 0.0100
# epi: 293 | score avg 286.07 | mem length: 10000 | epsilon: 0.0100
# epi: 294 | score avg 307.46 | mem length: 10000 | epsilon: 0.0100
# epi: 295 | score avg 326.72 | mem length: 10000 | epsilon: 0.0100
# epi: 296 | score avg 315.95 | mem length: 10000 | epsilon: 0.0100
# epi: 297 | score avg 334.35 | mem length: 10000 | epsilon: 0.0100
# epi: 298 | score avg 350.92 | mem length: 10000 | epsilon: 0.0100
# epi: 299 | score avg 344.02 | mem length: 10000 | epsilon: 0.0100
# epi: 300 | score avg 327.22 | mem length: 10000 | epsilon: 0.0100
# epi: 301 | score avg 309.90 | mem length: 10000 | epsilon: 0.0100
# epi: 302 | score avg 328.91 | mem length: 10000 | epsilon: 0.0100
# epi: 303 | score avg 309.02 | mem length: 10000 | epsilon: 0.0100
# epi: 304 | score avg 292.42 | mem length: 10000 | epsilon: 0.0100
# epi: 305 | score avg 291.48 | mem length: 10000 | epsilon: 0.0100
# epi: 306 | score avg 312.33 | mem length: 10000 | epsilon: 0.0100
# epi: 307 | score avg 310.19 | mem length: 10000 | epsilon: 0.0100
# epi: 308 | score avg 329.18 | mem length: 10000 | epsilon: 0.0100
# epi: 309 | score avg 335.36 | mem length: 10000 | epsilon: 0.0100
# epi: 310 | score avg 319.82 | mem length: 10000 | epsilon: 0.0100
# epi: 311 | score avg 337.84 | mem length: 10000 | epsilon: 0.0100
# epi: 312 | score avg 327.86 | mem length: 10000 | epsilon: 0.0100
# epi: 313 | score avg 301.97 | mem length: 10000 | epsilon: 0.0100
# epi: 314 | score avg 282.47 | mem length: 10000 | epsilon: 0.0100
# epi: 315 | score avg 263.03 | mem length: 10000 | epsilon: 0.0100
# epi: 316 | score avg 254.12 | mem length: 10000 | epsilon: 0.0100
# epi: 317 | score avg 258.11 | mem length: 10000 | epsilon: 0.0100
# epi: 318 | score avg 247.70 | mem length: 10000 | epsilon: 0.0100
# epi: 319 | score avg 238.03 | mem length: 10000 | epsilon: 0.0100
# epi: 320 | score avg 223.33 | mem length: 10000 | epsilon: 0.0100
# epi: 321 | score avg 210.39 | mem length: 10000 | epsilon: 0.0100
# epi: 322 | score avg 190.25 | mem length: 10000 | epsilon: 0.0100
# epi: 323 | score avg 172.23 | mem length: 10000 | epsilon: 0.0100
# epi: 324 | score avg 155.81 | mem length: 10000 | epsilon: 0.0100
# epi: 325 | score avg 141.33 | mem length: 10000 | epsilon: 0.0100
# epi: 326 | score avg 156.79 | mem length: 10000 | epsilon: 0.0100
# epi: 327 | score avg 191.11 | mem length: 10000 | epsilon: 0.0100
# epi: 328 | score avg 186.00 | mem length: 10000 | epsilon: 0.0100
# epi: 329 | score avg 183.60 | mem length: 10000 | epsilon: 0.0100
# epi: 330 | score avg 181.64 | mem length: 10000 | epsilon: 0.0100
# epi: 331 | score avg 180.88 | mem length: 10000 | epsilon: 0.0100
# epi: 332 | score avg 184.39 | mem length: 10000 | epsilon: 0.0100
# epi: 333 | score avg 186.05 | mem length: 10000 | epsilon: 0.0100
# epi: 334 | score avg 184.75 | mem length: 10000 | epsilon: 0.0100
# epi: 335 | score avg 182.57 | mem length: 10000 | epsilon: 0.0100
# epi: 336 | score avg 184.41 | mem length: 10000 | epsilon: 0.0100
# epi: 337 | score avg 187.37 | mem length: 10000 | epsilon: 0.0100
# epi: 338 | score avg 188.24 | mem length: 10000 | epsilon: 0.0100
# epi: 339 | score avg 185.41 | mem length: 10000 | epsilon: 0.0100
# epi: 340 | score avg 178.57 | mem length: 10000 | epsilon: 0.0100
# epi: 341 | score avg 175.31 | mem length: 10000 | epsilon: 0.0100
# epi: 342 | score avg 207.78 | mem length: 10000 | epsilon: 0.0100
# epi: 343 | score avg 237.00 | mem length: 10000 | epsilon: 0.0100
# epi: 344 | score avg 225.40 | mem length: 10000 | epsilon: 0.0100
# epi: 345 | score avg 212.36 | mem length: 10000 | epsilon: 0.0100
# epi: 346 | score avg 201.13 | mem length: 10000 | epsilon: 0.0100
# epi: 347 | score avg 188.81 | mem length: 10000 | epsilon: 0.0100
# epi: 348 | score avg 176.93 | mem length: 10000 | epsilon: 0.0100
# epi: 349 | score avg 164.74 | mem length: 10000 | epsilon: 0.0100
# epi: 350 | score avg 154.87 | mem length: 10000 | epsilon: 0.0100
# epi: 351 | score avg 143.78 | mem length: 10000 | epsilon: 0.0100
# epi: 352 | score avg 134.80 | mem length: 10000 | epsilon: 0.0100
# epi: 353 | score avg 127.42 | mem length: 10000 | epsilon: 0.0100
# epi: 354 | score avg 121.18 | mem length: 10000 | epsilon: 0.0100
# epi: 355 | score avg 116.26 | mem length: 10000 | epsilon: 0.0100
# epi: 356 | score avg 111.63 | mem length: 10000 | epsilon: 0.0100
# epi: 357 | score avg 109.77 | mem length: 10000 | epsilon: 0.0100
# epi: 358 | score avg 111.99 | mem length: 10000 | epsilon: 0.0100
# epi: 359 | score avg 130.59 | mem length: 10000 | epsilon: 0.0100
# epi: 360 | score avg 156.84 | mem length: 10000 | epsilon: 0.0100
# epi: 361 | score avg 148.45 | mem length: 10000 | epsilon: 0.0100
# epi: 362 | score avg 139.41 | mem length: 10000 | epsilon: 0.0100
# epi: 363 | score avg 131.77 | mem length: 10000 | epsilon: 0.0100
# epi: 364 | score avg 124.69 | mem length: 10000 | epsilon: 0.0100
# epi: 365 | score avg 118.32 | mem length: 10000 | epsilon: 0.0100
# epi: 366 | score avg 112.29 | mem length: 10000 | epsilon: 0.0100
# epi: 367 | score avg 110.06 | mem length: 10000 | epsilon: 0.0100
# epi: 368 | score avg 107.85 | mem length: 10000 | epsilon: 0.0100
# epi: 369 | score avg 106.77 | mem length: 10000 | epsilon: 0.0100
# epi: 370 | score avg 111.19 | mem length: 10000 | epsilon: 0.0100
# epi: 371 | score avg 150.07 | mem length: 10000 | epsilon: 0.0100
# epi: 372 | score avg 145.47 | mem length: 10000 | epsilon: 0.0100
# epi: 373 | score avg 140.22 | mem length: 10000 | epsilon: 0.0100
# epi: 374 | score avg 134.80 | mem length: 10000 | epsilon: 0.0100
# epi: 375 | score avg 128.12 | mem length: 10000 | epsilon: 0.0100
# epi: 376 | score avg 122.81 | mem length: 10000 | epsilon: 0.0100
# epi: 377 | score avg 116.42 | mem length: 10000 | epsilon: 0.0100
# epi: 378 | score avg 110.38 | mem length: 10000 | epsilon: 0.0100
# epi: 379 | score avg 105.54 | mem length: 10000 | epsilon: 0.0100
# epi: 380 | score avg 100.89 | mem length: 10000 | epsilon: 0.0100
# epi: 381 | score avg 97.80 | mem length: 10000 | epsilon: 0.0100
# epi: 382 | score avg 97.02 | mem length: 10000 | epsilon: 0.0100
# epi: 383 | score avg 95.52 | mem length: 10000 | epsilon: 0.0100
# epi: 384 | score avg 95.37 | mem length: 10000 | epsilon: 0.0100
# epi: 385 | score avg 99.83 | mem length: 10000 | epsilon: 0.0100
# epi: 386 | score avg 128.25 | mem length: 10000 | epsilon: 0.0100
# epi: 387 | score avg 130.62 | mem length: 10000 | epsilon: 0.0100
# epi: 388 | score avg 167.56 | mem length: 10000 | epsilon: 0.0100
# epi: 389 | score avg 200.80 | mem length: 10000 | epsilon: 0.0100
# epi: 390 | score avg 230.72 | mem length: 10000 | epsilon: 0.0100
# epi: 391 | score avg 257.65 | mem length: 10000 | epsilon: 0.0100
# epi: 392 | score avg 281.89 | mem length: 10000 | epsilon: 0.0100
# epi: 393 | score avg 303.70 | mem length: 10000 | epsilon: 0.0100
# epi: 394 | score avg 323.33 | mem length: 10000 | epsilon: 0.0100
# epi: 395 | score avg 309.70 | mem length: 10000 | epsilon: 0.0100
# epi: 396 | score avg 291.03 | mem length: 10000 | epsilon: 0.0100
# epi: 397 | score avg 267.82 | mem length: 10000 | epsilon: 0.0100
# epi: 398 | score avg 245.54 | mem length: 10000 | epsilon: 0.0100
# epi: 399 | score avg 227.09 | mem length: 10000 | epsilon: 0.0100
# epi: 400 | score avg 209.08 | mem length: 10000 | epsilon: 0.0100
# epi: 401 | score avg 193.67 | mem length: 10000 | epsilon: 0.0100
# epi: 402 | score avg 179.50 | mem length: 10000 | epsilon: 0.0100
# epi: 403 | score avg 167.45 | mem length: 10000 | epsilon: 0.0100
# epi: 404 | score avg 157.71 | mem length: 10000 | epsilon: 0.0100
# epi: 405 | score avg 147.74 | mem length: 10000 | epsilon: 0.0100
# epi: 406 | score avg 140.66 | mem length: 10000 | epsilon: 0.0100
# epi: 407 | score avg 131.90 | mem length: 10000 | epsilon: 0.0100
# epi: 408 | score avg 125.81 | mem length: 10000 | epsilon: 0.0100
# epi: 409 | score avg 119.33 | mem length: 10000 | epsilon: 0.0100
# epi: 410 | score avg 113.89 | mem length: 10000 | epsilon: 0.0100
# epi: 411 | score avg 108.20 | mem length: 10000 | epsilon: 0.0100
# epi: 412 | score avg 104.78 | mem length: 10000 | epsilon: 0.0100
# epi: 413 | score avg 100.91 | mem length: 10000 | epsilon: 0.0100
# epi: 414 | score avg 98.31 | mem length: 10000 | epsilon: 0.0100
# epi: 415 | score avg 97.78 | mem length: 10000 | epsilon: 0.0100
# epi: 416 | score avg 95.61 | mem length: 10000 | epsilon: 0.0100
# epi: 417 | score avg 93.64 | mem length: 10000 | epsilon: 0.0100
# epi: 418 | score avg 91.18 | mem length: 10000 | epsilon: 0.0100
# epi: 419 | score avg 101.56 | mem length: 10000 | epsilon: 0.0100
# epi: 420 | score avg 120.31 | mem length: 10000 | epsilon: 0.0100
# epi: 421 | score avg 158.28 | mem length: 10000 | epsilon: 0.0100
# epi: 422 | score avg 192.45 | mem length: 10000 | epsilon: 0.0100
# epi: 423 | score avg 223.20 | mem length: 10000 | epsilon: 0.0100
# epi: 424 | score avg 250.88 | mem length: 10000 | epsilon: 0.0100
# epi: 425 | score avg 275.79 | mem length: 10000 | epsilon: 0.0100
# epi: 426 | score avg 298.22 | mem length: 10000 | epsilon: 0.0100
# epi: 427 | score avg 278.59 | mem length: 10000 | epsilon: 0.0100
# epi: 428 | score avg 288.33 | mem length: 10000 | epsilon: 0.0100
# epi: 429 | score avg 270.00 | mem length: 10000 | epsilon: 0.0100
# epi: 430 | score avg 252.00 | mem length: 10000 | epsilon: 0.0100
# epi: 431 | score avg 236.20 | mem length: 10000 | epsilon: 0.0100
# epi: 432 | score avg 221.08 | mem length: 10000 | epsilon: 0.0100
# epi: 433 | score avg 207.47 | mem length: 10000 | epsilon: 0.0100
# epi: 434 | score avg 196.93 | mem length: 10000 | epsilon: 0.0100
# epi: 435 | score avg 186.43 | mem length: 10000 | epsilon: 0.0100
# epi: 436 | score avg 178.99 | mem length: 10000 | epsilon: 0.0100
# epi: 437 | score avg 172.89 | mem length: 10000 | epsilon: 0.0100
# epi: 438 | score avg 169.80 | mem length: 10000 | epsilon: 0.0100
# epi: 439 | score avg 168.92 | mem length: 10000 | epsilon: 0.0100
# epi: 440 | score avg 194.03 | mem length: 10000 | epsilon: 0.0100
# epi: 441 | score avg 201.13 | mem length: 10000 | epsilon: 0.0100
# epi: 442 | score avg 231.01 | mem length: 10000 | epsilon: 0.0100
# epi: 443 | score avg 218.11 | mem length: 10000 | epsilon: 0.0100
# epi: 444 | score avg 246.30 | mem length: 10000 | epsilon: 0.0100
# epi: 445 | score avg 271.67 | mem length: 10000 | epsilon: 0.0100
# epi: 446 | score avg 294.50 | mem length: 10000 | epsilon: 0.0100
# epi: 447 | score avg 315.05 | mem length: 10000 | epsilon: 0.0100
# epi: 448 | score avg 333.55 | mem length: 10000 | epsilon: 0.0100
# epi: 449 | score avg 350.19 | mem length: 10000 | epsilon: 0.0100
# epi: 450 | score avg 338.37 | mem length: 10000 | epsilon: 0.0100
# epi: 451 | score avg 354.54 | mem length: 10000 | epsilon: 0.0100
# epi: 452 | score avg 356.78 | mem length: 10000 | epsilon: 0.0100
# epi: 453 | score avg 353.90 | mem length: 10000 | epsilon: 0.0100
# epi: 454 | score avg 368.51 | mem length: 10000 | epsilon: 0.0100
# epi: 455 | score avg 356.96 | mem length: 10000 | epsilon: 0.0100
# epi: 456 | score avg 346.47 | mem length: 10000 | epsilon: 0.0100
# epi: 457 | score avg 330.72 | mem length: 10000 | epsilon: 0.0100
# epi: 458 | score avg 315.95 | mem length: 10000 | epsilon: 0.0100
# epi: 459 | score avg 299.95 | mem length: 10000 | epsilon: 0.0100
# epi: 460 | score avg 283.16 | mem length: 10000 | epsilon: 0.0100
# epi: 461 | score avg 267.04 | mem length: 10000 | epsilon: 0.0100
# epi: 462 | score avg 255.04 | mem length: 10000 | epsilon: 0.0100
# epi: 463 | score avg 243.83 | mem length: 10000 | epsilon: 0.0100
# epi: 464 | score avg 236.15 | mem length: 10000 | epsilon: 0.0100
# epi: 465 | score avg 224.84 | mem length: 10000 | epsilon: 0.0100
# epi: 466 | score avg 211.15 | mem length: 10000 | epsilon: 0.0100
# epi: 467 | score avg 202.04 | mem length: 10000 | epsilon: 0.0100
# epi: 468 | score avg 190.33 | mem length: 10000 | epsilon: 0.0100
# epi: 469 | score avg 182.30 | mem length: 10000 | epsilon: 0.0100
# epi: 470 | score avg 174.37 | mem length: 10000 | epsilon: 0.0100
# epi: 471 | score avg 166.33 | mem length: 10000 | epsilon: 0.0100
# epi: 472 | score avg 162.70 | mem length: 10000 | epsilon: 0.0100
# epi: 473 | score avg 158.13 | mem length: 10000 | epsilon: 0.0100
# epi: 474 | score avg 155.42 | mem length: 10000 | epsilon: 0.0100
# epi: 475 | score avg 150.27 | mem length: 10000 | epsilon: 0.0100
# epi: 476 | score avg 146.75 | mem length: 10000 | epsilon: 0.0100
# epi: 477 | score avg 141.77 | mem length: 10000 | epsilon: 0.0100
# epi: 478 | score avg 137.40 | mem length: 10000 | epsilon: 0.0100
# epi: 479 | score avg 132.86 | mem length: 10000 | epsilon: 0.0100
# epi: 480 | score avg 131.77 | mem length: 10000 | epsilon: 0.0100
# epi: 481 | score avg 126.99 | mem length: 10000 | epsilon: 0.0100
# epi: 482 | score avg 123.09 | mem length: 10000 | epsilon: 0.0100
# epi: 483 | score avg 119.28 | mem length: 10000 | epsilon: 0.0100
# epi: 484 | score avg 115.66 | mem length: 10000 | epsilon: 0.0100
# epi: 485 | score avg 115.49 | mem length: 10000 | epsilon: 0.0100
# epi: 486 | score avg 116.04 | mem length: 10000 | epsilon: 0.0100
# epi: 487 | score avg 116.64 | mem length: 10000 | epsilon: 0.0100
# epi: 488 | score avg 116.37 | mem length: 10000 | epsilon: 0.0100
# epi: 489 | score avg 114.84 | mem length: 10000 | epsilon: 0.0100
# epi: 490 | score avg 114.65 | mem length: 10000 | epsilon: 0.0100
# epi: 491 | score avg 117.19 | mem length: 10000 | epsilon: 0.0100
# epi: 492 | score avg 119.47 | mem length: 10000 | epsilon: 0.0100
# epi: 493 | score avg 120.02 | mem length: 10000 | epsilon: 0.0100
# epi: 494 | score avg 131.02 | mem length: 10000 | epsilon: 0.0100
# epi: 495 | score avg 130.52 | mem length: 10000 | epsilon: 0.0100
# epi: 496 | score avg 147.27 | mem length: 10000 | epsilon: 0.0100
# epi: 497 | score avg 145.94 | mem length: 10000 | epsilon: 0.0100
# epi: 498 | score avg 145.55 | mem length: 10000 | epsilon: 0.0100
# epi: 499 | score avg 149.69 | mem length: 10000 | epsilon: 0.0100
# epi: 500 | score avg 149.02 | mem length: 10000 | epsilon: 0.0100
# epi: 501 | score avg 142.82 | mem length: 10000 | epsilon: 0.0100
# epi: 502 | score avg 137.64 | mem length: 10000 | epsilon: 0.0100
# epi: 503 | score avg 151.27 | mem length: 10000 | epsilon: 0.0100
# epi: 504 | score avg 150.05 | mem length: 10000 | epsilon: 0.0100
# epi: 505 | score avg 152.24 | mem length: 10000 | epsilon: 0.0100
# epi: 506 | score avg 149.72 | mem length: 10000 | epsilon: 0.0100
# epi: 507 | score avg 142.75 | mem length: 10000 | epsilon: 0.0100
# epi: 508 | score avg 136.87 | mem length: 10000 | epsilon: 0.0100
# epi: 509 | score avg 131.08 | mem length: 10000 | epsilon: 0.0100
# epi: 510 | score avg 134.68 | mem length: 10000 | epsilon: 0.0100
# epi: 511 | score avg 130.71 | mem length: 10000 | epsilon: 0.0100
# epi: 512 | score avg 133.14 | mem length: 10000 | epsilon: 0.0100
# epi: 513 | score avg 130.12 | mem length: 10000 | epsilon: 0.0100
# epi: 514 | score avg 133.91 | mem length: 10000 | epsilon: 0.0100
# epi: 515 | score avg 133.72 | mem length: 10000 | epsilon: 0.0100
# epi: 516 | score avg 128.85 | mem length: 10000 | epsilon: 0.0100
# epi: 517 | score avg 128.96 | mem length: 10000 | epsilon: 0.0100
# epi: 518 | score avg 146.57 | mem length: 10000 | epsilon: 0.0100
# epi: 519 | score avg 138.81 | mem length: 10000 | epsilon: 0.0100
# epi: 520 | score avg 153.43 | mem length: 10000 | epsilon: 0.0100
# epi: 521 | score avg 184.39 | mem length: 10000 | epsilon: 0.0100
# epi: 522 | score avg 215.95 | mem length: 10000 | epsilon: 0.0100
# epi: 523 | score avg 198.45 | mem length: 10000 | epsilon: 0.0100
# epi: 524 | score avg 180.71 | mem length: 10000 | epsilon: 0.0100
# epi: 525 | score avg 164.04 | mem length: 10000 | epsilon: 0.0100
# epi: 526 | score avg 148.93 | mem length: 10000 | epsilon: 0.0100
# epi: 527 | score avg 134.84 | mem length: 10000 | epsilon: 0.0100
# epi: 528 | score avg 122.46 | mem length: 10000 | epsilon: 0.0100
# epi: 529 | score avg 111.61 | mem length: 10000 | epsilon: 0.0100
# epi: 530 | score avg 101.45 | mem length: 10000 | epsilon: 0.0100
# epi: 531 | score avg 92.10 | mem length: 10000 | epsilon: 0.0100
# epi: 532 | score avg 86.59 | mem length: 10000 | epsilon: 0.0100
# epi: 533 | score avg 88.13 | mem length: 10000 | epsilon: 0.0100
# epi: 534 | score avg 80.22 | mem length: 10000 | epsilon: 0.0100
# epi: 535 | score avg 73.10 | mem length: 10000 | epsilon: 0.0100
# epi: 536 | score avg 66.69 | mem length: 10000 | epsilon: 0.0100
# epi: 537 | score avg 60.92 | mem length: 10000 | epsilon: 0.0100
# epi: 538 | score avg 55.83 | mem length: 10000 | epsilon: 0.0100
# epi: 539 | score avg 51.05 | mem length: 10000 | epsilon: 0.0100
# epi: 540 | score avg 46.84 | mem length: 10000 | epsilon: 0.0100
# epi: 541 | score avg 43.26 | mem length: 10000 | epsilon: 0.0100
# epi: 542 | score avg 39.83 | mem length: 10000 | epsilon: 0.0100
# epi: 543 | score avg 36.95 | mem length: 10000 | epsilon: 0.0100
# epi: 544 | score avg 34.05 | mem length: 10000 | epsilon: 0.0100
# epi: 545 | score avg 31.55 | mem length: 10000 | epsilon: 0.0100
# epi: 546 | score avg 29.39 | mem length: 10000 | epsilon: 0.0100
# epi: 547 | score avg 27.45 | mem length: 10000 | epsilon: 0.0100
# epi: 548 | score avg 25.71 | mem length: 10000 | epsilon: 0.0100
# epi: 549 | score avg 73.14 | mem length: 10000 | epsilon: 0.0100
# epi: 550 | score avg 80.72 | mem length: 10000 | epsilon: 0.0100
# epi: 551 | score avg 88.55 | mem length: 10000 | epsilon: 0.0100
# epi: 552 | score avg 129.70 | mem length: 10000 | epsilon: 0.0100
# epi: 553 | score avg 166.73 | mem length: 10000 | epsilon: 0.0100
# epi: 554 | score avg 200.05 | mem length: 10000 | epsilon: 0.0100
# epi: 555 | score avg 230.05 | mem length: 10000 | epsilon: 0.0100
# epi: 556 | score avg 251.14 | mem length: 10000 | epsilon: 0.0100
# epi: 557 | score avg 256.93 | mem length: 10000 | epsilon: 0.0100
# epi: 558 | score avg 257.14 | mem length: 10000 | epsilon: 0.0100
# epi: 559 | score avg 281.42 | mem length: 10000 | epsilon: 0.0100
# epi: 560 | score avg 303.28 | mem length: 10000 | epsilon: 0.0100
# epi: 561 | score avg 322.95 | mem length: 10000 | epsilon: 0.0100
# epi: 562 | score avg 340.66 | mem length: 10000 | epsilon: 0.0100
# epi: 563 | score avg 356.59 | mem length: 10000 | epsilon: 0.0100
# epi: 564 | score avg 370.93 | mem length: 10000 | epsilon: 0.0100
# epi: 565 | score avg 383.84 | mem length: 10000 | epsilon: 0.0100
# epi: 566 | score avg 395.46 | mem length: 10000 | epsilon: 0.0100
# epi: 567 | score avg 405.91 | mem length: 10000 | epsilon: 0.0100
# End
