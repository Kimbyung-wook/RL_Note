# %%
# It is good to refer github following as : 
# https://github.com/shivaverma/OpenAIGym/blob/master/lunar-lander/discrete/lunar_lander.py
import gym
import sys
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from collections import deque
from tensorflow.keras.layers import Dense

# %%
class DQN(tf.keras.Model):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = Dense(64,activation='relu')
        self.fc2 = Dense(64,activation='relu')
        self.out = Dense(action_size,kernel_initializer=tf.keras.initializers.RandomUniform(-1e-3,1e-3))

    def call(self,x):
        x = self.fc1(x)
        x = self.fc2(x)
        q = self.out(x)
        return q

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size= action_size
        
        # Hyper params for learning
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        
        # Experience Replay
        self.batch_size = 64
        self.train_start = 1000
        self.memory = deque(maxlen=5000)
        
        self.model        = DQN(self.state_size, self.action_size)
        self.target_model = DQN(self.state_size, self.action_size)
        self.optimizer = tf.keras.optimizers.Adam(lr=self.learning_rate)
        
        self.update_target_model()
        
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())
        
    def choose_action(self,state):
        # Exploration and Exploitation
        if (np.random.rand() <= self.epsilon):
            return random.randrange(self.action_size)
        else:
            return np.argmax(self.model.predict(state))
        
    def train_model(self, state, action, reward, next_state, done):
        # Train from Experience Replay
        if len(self.memory) < self.train_start:
            return 0.0
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        mini_batch = random.sample(self.memory, self.batch_size)
        
        states      = np.array([sample[0][0] for sample in mini_batch])
        actions     = np.array([sample[1] for sample in mini_batch])
        rewards     = np.array([sample[2] for sample in mini_batch])
        next_states = np.array([sample[3][0] for sample in mini_batch])
        dones       = np.array([sample[4] for sample in mini_batch])
        
        
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            predicts = self.model(states)
            one_hot_action = tf.one_hot(actions, self.action_size)
            predicts = tf.reduce_sum(one_hot_action * predicts, axis=1)
            
            target_predicts = self.target_model(next_states)
            target_predicts = tf.stop_gradient(target_predicts)
            
            max_q = np.amax(target_predicts, axis=-1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q
            loss = tf.reduce_mean(tf.square(targets - predicts))
            
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))
        return loss

# %%
# %matplotlib tk

ENV_NAME = 'LunarLander-v2'
EPISODES = 1000

if __name__ == "__main__":
    env = gym.make(ENV_NAME)
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    agent = DQNAgent(state_size, action_size)
    print('Env Name : ',ENV_NAME)
    print('States {}, Actions {}'
            .format(state_size, action_size))

    scores, episodes, epsilons, losses = [], [], [], []
    score_avg = 0
    
    end = False
    
    fig = plt.figure(1)
    fig.clf()
    
    for e in range(EPISODES):
        done = False
        score = 0
        loss_list = []

        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            #env.render()

            action = agent.choose_action(state)
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            score += reward
            reward = 0.1 if not done or score == 500 else -1

            agent.remember(state, action, reward, next_state, done)

            loss = agent.train_model(state, action, reward, next_state, done)
            loss_list.append(loss)

            state = next_state
            if done:
                agent.update_target_model()

                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print('epi: {:3d} | score avg {:3.2f} | mem length: {:4d} | epsilon: {:.4f}'
                      .format(e, score_avg, len(agent.memory), agent.epsilon))

                episodes.append(e)
                scores.append(score_avg)
                epsilons.append(agent.epsilon)
                losses.append(np.mean(loss_list))
                plt.subplot(311)
                plt.plot(episodes, scores, 'b')
                plt.xlabel('episode')
                plt.ylabel('average score')
                plt.title('LunarLanderv2 DQN')
                plt.grid()
                
                plt.subplot(312)
                plt.plot(episodes, epsilons, 'b')
                plt.xlabel('episode')
                plt.ylabel('epsilon')
                plt.grid()
                
                plt.subplot(313)
                plt.plot(episodes, losses, 'b')
                plt.xlabel('episode')
                plt.ylabel('losses')
                plt.grid()
                
                plt.savefig('./save_model/LunarLanderv2_dqn.png')

                if score_avg > 200:
                    agent.model.save_weights('./save_model/LunarLanderv2_dqn', save_format='tf')
                    end = True
                    break
        if end == True:
            env.close()
            np.save('./save_model/LunarLanderv2_dqn_epi',  episodes)
            np.save('./save_model/LunarLanderv2_dqn_score',scores)
            np.save('./save_model/LunarLanderv2_dqn_loss', losses)
            print("End")
            break
# Out:
# Env Name :  LunarLander-v2
# States 8, Actions 4
# epi:   0 | score avg -163.26 | mem length:   68 | epsilon: 1.0000
# epi:   1 | score avg -157.97 | mem length:  142 | epsilon: 1.0000
# epi:   2 | score avg -154.44 | mem length:  277 | epsilon: 1.0000
# epi:   3 | score avg -161.97 | mem length:  360 | epsilon: 1.0000
# epi:   4 | score avg -157.27 | mem length:  473 | epsilon: 1.0000
# epi:   5 | score avg -192.35 | mem length:  551 | epsilon: 1.0000
# epi:   6 | score avg -211.57 | mem length:  673 | epsilon: 1.0000
# epi:   7 | score avg -200.16 | mem length:  752 | epsilon: 1.0000
# epi:   8 | score avg -231.88 | mem length:  872 | epsilon: 1.0000
# epi:   9 | score avg -220.49 | mem length:  944 | epsilon: 1.0000
# epi:  10 | score avg -206.30 | mem length: 1023 | epsilon: 0.9763
# epi:  11 | score avg -192.27 | mem length: 1089 | epsilon: 0.9139
# epi:  12 | score avg -194.42 | mem length: 1183 | epsilon: 0.8319
# epi:  13 | score avg -194.85 | mem length: 1269 | epsilon: 0.7633
# epi:  14 | score avg -186.25 | mem length: 1336 | epsilon: 0.7138
# epi:  15 | score avg -175.10 | mem length: 1407 | epsilon: 0.6648
# epi:  16 | score avg -172.76 | mem length: 1512 | epsilon: 0.5985
# epi:  17 | score avg -169.49 | mem length: 1586 | epsilon: 0.5558
# epi:  18 | score avg -182.11 | mem length: 1657 | epsilon: 0.5177
# epi:  19 | score avg -198.73 | mem length: 1779 | epsilon: 0.4582
# epi:  20 | score avg -193.34 | mem length: 1844 | epsilon: 0.4294
# epi:  21 | score avg -205.49 | mem length: 1925 | epsilon: 0.3960
# epi:  22 | score avg -183.47 | mem length: 2010 | epsilon: 0.3637
# epi:  23 | score avg -185.56 | mem length: 2075 | epsilon: 0.3408
# epi:  24 | score avg -194.41 | mem length: 2127 | epsilon: 0.3235
# epi:  25 | score avg -209.45 | mem length: 2182 | epsilon: 0.3062
# epi:  26 | score avg -226.12 | mem length: 2264 | epsilon: 0.2821
# epi:  27 | score avg -259.29 | mem length: 2336 | epsilon: 0.2625
# epi:  28 | score avg -292.25 | mem length: 2430 | epsilon: 0.2389
# epi:  29 | score avg -279.90 | mem length: 2494 | epsilon: 0.2241
# epi:  30 | score avg -278.95 | mem length: 2555 | epsilon: 0.2108
# epi:  31 | score avg -281.99 | mem length: 2642 | epsilon: 0.1932
# epi:  32 | score avg -301.87 | mem length: 2731 | epsilon: 0.1768
# epi:  33 | score avg -283.74 | mem length: 2802 | epsilon: 0.1647
# epi:  34 | score avg -292.78 | mem length: 2884 | epsilon: 0.1517
# epi:  35 | score avg -311.24 | mem length: 2979 | epsilon: 0.1379
# epi:  36 | score avg -296.47 | mem length: 3067 | epsilon: 0.1263
# epi:  37 | score avg -270.11 | mem length: 3125 | epsilon: 0.1192
# epi:  38 | score avg -273.44 | mem length: 3205 | epsilon: 0.1100
# epi:  39 | score avg -271.17 | mem length: 3277 | epsilon: 0.1024
# epi:  40 | score avg -253.78 | mem length: 3363 | epsilon: 0.0939
# epi:  41 | score avg -259.82 | mem length: 3438 | epsilon: 0.0871
# epi:  42 | score avg -251.38 | mem length: 3501 | epsilon: 0.0818
# epi:  43 | score avg -284.00 | mem length: 3600 | epsilon: 0.0741
# epi:  44 | score avg -289.45 | mem length: 3669 | epsilon: 0.0692
# epi:  45 | score avg -267.68 | mem length: 3746 | epsilon: 0.0640
# epi:  46 | score avg -269.27 | mem length: 3798 | epsilon: 0.0608
# epi:  47 | score avg -274.92 | mem length: 3865 | epsilon: 0.0568
# epi:  48 | score avg -259.31 | mem length: 3927 | epsilon: 0.0534
# epi:  49 | score avg -267.80 | mem length: 3993 | epsilon: 0.0500
# epi:  50 | score avg -277.82 | mem length: 4096 | epsilon: 0.0451
# epi:  51 | score avg -262.26 | mem length: 4156 | epsilon: 0.0425
# epi:  52 | score avg -264.41 | mem length: 4250 | epsilon: 0.0387
# epi:  53 | score avg -256.87 | mem length: 4310 | epsilon: 0.0364
# epi:  54 | score avg -261.93 | mem length: 4366 | epsilon: 0.0344
# epi:  55 | score avg -252.55 | mem length: 4431 | epsilon: 0.0323
# epi:  56 | score avg -253.89 | mem length: 4509 | epsilon: 0.0298
# epi:  57 | score avg -236.16 | mem length: 4578 | epsilon: 0.0279
# epi:  58 | score avg -237.75 | mem length: 4671 | epsilon: 0.0254
# epi:  59 | score avg -236.04 | mem length: 4767 | epsilon: 0.0231
# epi:  60 | score avg -247.41 | mem length: 4831 | epsilon: 0.0216
# epi:  61 | score avg -231.83 | mem length: 4924 | epsilon: 0.0197
# epi:  62 | score avg -247.85 | mem length: 5000 | epsilon: 0.0180
# epi:  63 | score avg -265.00 | mem length: 5000 | epsilon: 0.0162
# epi:  64 | score avg -263.27 | mem length: 5000 | epsilon: 0.0148
# epi:  65 | score avg -249.42 | mem length: 5000 | epsilon: 0.0136
# epi:  66 | score avg -237.83 | mem length: 5000 | epsilon: 0.0120
# epi:  67 | score avg -226.56 | mem length: 5000 | epsilon: 0.0109
# epi:  68 | score avg -215.71 | mem length: 5000 | epsilon: 0.0100
# epi:  69 | score avg -235.12 | mem length: 5000 | epsilon: 0.0100
# epi:  70 | score avg -223.45 | mem length: 5000 | epsilon: 0.0100
# epi:  71 | score avg -236.70 | mem length: 5000 | epsilon: 0.0100
# epi:  72 | score avg -258.13 | mem length: 5000 | epsilon: 0.0100
# epi:  73 | score avg -245.94 | mem length: 5000 | epsilon: 0.0100
# epi:  74 | score avg -264.34 | mem length: 5000 | epsilon: 0.0100
# epi:  75 | score avg -272.94 | mem length: 5000 | epsilon: 0.0100
# epi:  76 | score avg -283.82 | mem length: 5000 | epsilon: 0.0100
# epi:  77 | score avg -290.16 | mem length: 5000 | epsilon: 0.0100
# epi:  78 | score avg -298.35 | mem length: 5000 | epsilon: 0.0100
# epi:  79 | score avg -293.06 | mem length: 5000 | epsilon: 0.0100
# epi:  80 | score avg -296.21 | mem length: 5000 | epsilon: 0.0100
# epi:  81 | score avg -292.77 | mem length: 5000 | epsilon: 0.0100
# epi:  82 | score avg -300.72 | mem length: 5000 | epsilon: 0.0100
# epi:  83 | score avg -287.34 | mem length: 5000 | epsilon: 0.0100
# epi:  84 | score avg -293.75 | mem length: 5000 | epsilon: 0.0100
# epi:  85 | score avg -301.96 | mem length: 5000 | epsilon: 0.0100
# epi:  86 | score avg -289.02 | mem length: 5000 | epsilon: 0.0100
# epi:  87 | score avg -286.68 | mem length: 5000 | epsilon: 0.0100
# epi:  88 | score avg -287.10 | mem length: 5000 | epsilon: 0.0100
# epi:  89 | score avg -310.45 | mem length: 5000 | epsilon: 0.0100
# epi:  90 | score avg -301.78 | mem length: 5000 | epsilon: 0.0100
# epi:  91 | score avg -316.09 | mem length: 5000 | epsilon: 0.0100
# epi:  92 | score avg -309.35 | mem length: 5000 | epsilon: 0.0100
# epi:  93 | score avg -309.52 | mem length: 5000 | epsilon: 0.0100
# epi:  94 | score avg -307.94 | mem length: 5000 | epsilon: 0.0100
# epi:  95 | score avg -320.29 | mem length: 5000 | epsilon: 0.0100
# epi:  96 | score avg -328.54 | mem length: 5000 | epsilon: 0.0100
# epi:  97 | score avg -333.28 | mem length: 5000 | epsilon: 0.0100
# epi:  98 | score avg -327.10 | mem length: 5000 | epsilon: 0.0100
# epi:  99 | score avg -310.10 | mem length: 5000 | epsilon: 0.0100
# epi: 100 | score avg -292.20 | mem length: 5000 | epsilon: 0.0100
# epi: 101 | score avg -318.60 | mem length: 5000 | epsilon: 0.0100
# epi: 102 | score avg -305.50 | mem length: 5000 | epsilon: 0.0100
# epi: 103 | score avg -343.69 | mem length: 5000 | epsilon: 0.0100
# epi: 104 | score avg -377.48 | mem length: 5000 | epsilon: 0.0100
# epi: 105 | score avg -359.01 | mem length: 5000 | epsilon: 0.0100
# epi: 106 | score avg -343.72 | mem length: 5000 | epsilon: 0.0100
# epi: 107 | score avg -349.24 | mem length: 5000 | epsilon: 0.0100
# epi: 108 | score avg -360.62 | mem length: 5000 | epsilon: 0.0100
# epi: 109 | score avg -392.44 | mem length: 5000 | epsilon: 0.0100
# epi: 110 | score avg -435.70 | mem length: 5000 | epsilon: 0.0100
# epi: 111 | score avg -452.23 | mem length: 5000 | epsilon: 0.0100
# epi: 112 | score avg -481.56 | mem length: 5000 | epsilon: 0.0100
# epi: 113 | score avg -449.98 | mem length: 5000 | epsilon: 0.0100
# epi: 114 | score avg -480.32 | mem length: 5000 | epsilon: 0.0100
# epi: 115 | score avg -475.21 | mem length: 5000 | epsilon: 0.0100
# epi: 116 | score avg -456.07 | mem length: 5000 | epsilon: 0.0100
# epi: 117 | score avg -457.80 | mem length: 5000 | epsilon: 0.0100
# epi: 118 | score avg -445.97 | mem length: 5000 | epsilon: 0.0100
# epi: 119 | score avg -488.01 | mem length: 5000 | epsilon: 0.0100
# epi: 120 | score avg -469.41 | mem length: 5000 | epsilon: 0.0100
# epi: 121 | score avg -456.95 | mem length: 5000 | epsilon: 0.0100
# epi: 122 | score avg -437.02 | mem length: 5000 | epsilon: 0.0100
# epi: 123 | score avg -425.16 | mem length: 5000 | epsilon: 0.0100
# epi: 124 | score avg -399.90 | mem length: 5000 | epsilon: 0.0100
# epi: 125 | score avg -395.52 | mem length: 5000 | epsilon: 0.0100
# epi: 126 | score avg -381.40 | mem length: 5000 | epsilon: 0.0100
# epi: 127 | score avg -390.18 | mem length: 5000 | epsilon: 0.0100
# epi: 128 | score avg -402.70 | mem length: 5000 | epsilon: 0.0100
# epi: 129 | score avg -396.84 | mem length: 5000 | epsilon: 0.0100
# epi: 130 | score avg -398.33 | mem length: 5000 | epsilon: 0.0100
# epi: 131 | score avg -422.79 | mem length: 5000 | epsilon: 0.0100
# epi: 132 | score avg -445.32 | mem length: 5000 | epsilon: 0.0100
# epi: 133 | score avg -466.75 | mem length: 5000 | epsilon: 0.0100
# epi: 134 | score avg -431.84 | mem length: 5000 | epsilon: 0.0100
# epi: 135 | score avg -435.27 | mem length: 5000 | epsilon: 0.0100
# epi: 136 | score avg -494.57 | mem length: 5000 | epsilon: 0.0100
# epi: 137 | score avg -492.31 | mem length: 5000 | epsilon: 0.0100
# epi: 138 | score avg -484.07 | mem length: 5000 | epsilon: 0.0100
# epi: 139 | score avg -486.76 | mem length: 5000 | epsilon: 0.0100
# epi: 140 | score avg -451.42 | mem length: 5000 | epsilon: 0.0100
# epi: 141 | score avg -450.38 | mem length: 5000 | epsilon: 0.0100
# epi: 142 | score avg -478.34 | mem length: 5000 | epsilon: 0.0100
# epi: 143 | score avg -462.77 | mem length: 5000 | epsilon: 0.0100
# epi: 144 | score avg -447.08 | mem length: 5000 | epsilon: 0.0100
# epi: 145 | score avg -468.96 | mem length: 5000 | epsilon: 0.0100
# epi: 146 | score avg -506.75 | mem length: 5000 | epsilon: 0.0100
# epi: 147 | score avg -503.47 | mem length: 5000 | epsilon: 0.0100
# epi: 148 | score avg -493.27 | mem length: 5000 | epsilon: 0.0100
# epi: 149 | score avg -533.26 | mem length: 5000 | epsilon: 0.0100
# epi: 150 | score avg -505.27 | mem length: 5000 | epsilon: 0.0100
# epi: 151 | score avg -485.14 | mem length: 5000 | epsilon: 0.0100
# epi: 152 | score avg -482.18 | mem length: 5000 | epsilon: 0.0100
# epi: 153 | score avg -465.76 | mem length: 5000 | epsilon: 0.0100
# epi: 154 | score avg -480.67 | mem length: 5000 | epsilon: 0.0100
# epi: 155 | score avg -479.70 | mem length: 5000 | epsilon: 0.0100
# epi: 156 | score avg -455.44 | mem length: 5000 | epsilon: 0.0100
# epi: 157 | score avg -448.28 | mem length: 5000 | epsilon: 0.0100
# epi: 158 | score avg -439.49 | mem length: 5000 | epsilon: 0.0100
# epi: 159 | score avg -445.16 | mem length: 5000 | epsilon: 0.0100
# epi: 160 | score avg -456.71 | mem length: 5000 | epsilon: 0.0100
# epi: 161 | score avg -460.04 | mem length: 5000 | epsilon: 0.0100
# epi: 162 | score avg -445.39 | mem length: 5000 | epsilon: 0.0100
# epi: 163 | score avg -431.40 | mem length: 5000 | epsilon: 0.0100
# epi: 164 | score avg -422.21 | mem length: 5000 | epsilon: 0.0100
# epi: 165 | score avg -431.84 | mem length: 5000 | epsilon: 0.0100
# epi: 166 | score avg -443.14 | mem length: 5000 | epsilon: 0.0100
# epi: 167 | score avg -433.14 | mem length: 5000 | epsilon: 0.0100
# epi: 168 | score avg -431.77 | mem length: 5000 | epsilon: 0.0100
# epi: 169 | score avg -431.85 | mem length: 5000 | epsilon: 0.0100
# epi: 170 | score avg -426.47 | mem length: 5000 | epsilon: 0.0100
# epi: 171 | score avg -402.92 | mem length: 5000 | epsilon: 0.0100
# epi: 172 | score avg -428.73 | mem length: 5000 | epsilon: 0.0100
# epi: 173 | score avg -419.57 | mem length: 5000 | epsilon: 0.0100
# epi: 174 | score avg -420.25 | mem length: 5000 | epsilon: 0.0100
# epi: 175 | score avg -402.17 | mem length: 5000 | epsilon: 0.0100
# epi: 176 | score avg -414.31 | mem length: 5000 | epsilon: 0.0100
# epi: 177 | score avg -416.02 | mem length: 5000 | epsilon: 0.0100
# epi: 178 | score avg -466.29 | mem length: 5000 | epsilon: 0.0100
# epi: 179 | score avg -474.60 | mem length: 5000 | epsilon: 0.0100
# epi: 180 | score avg -484.66 | mem length: 5000 | epsilon: 0.0100
# epi: 181 | score avg -522.98 | mem length: 5000 | epsilon: 0.0100
# epi: 182 | score avg -510.10 | mem length: 5000 | epsilon: 0.0100
# epi: 183 | score avg -544.17 | mem length: 5000 | epsilon: 0.0100
# epi: 184 | score avg -873.52 | mem length: 5000 | epsilon: 0.0100
# epi: 185 | score avg -865.14 | mem length: 5000 | epsilon: 0.0100
# epi: 186 | score avg -814.46 | mem length: 5000 | epsilon: 0.0100
# epi: 187 | score avg -862.01 | mem length: 5000 | epsilon: 0.0100
# epi: 188 | score avg -829.18 | mem length: 5000 | epsilon: 0.0100
# epi: 189 | score avg -780.65 | mem length: 5000 | epsilon: 0.0100
# epi: 190 | score avg -746.88 | mem length: 5000 | epsilon: 0.0100
# epi: 191 | score avg -719.47 | mem length: 5000 | epsilon: 0.0100
# epi: 192 | score avg -663.00 | mem length: 5000 | epsilon: 0.0100
# epi: 193 | score avg -619.84 | mem length: 5000 | epsilon: 0.0100
# epi: 194 | score avg -766.40 | mem length: 5000 | epsilon: 0.0100
# epi: 195 | score avg -724.39 | mem length: 5000 | epsilon: 0.0100
# epi: 196 | score avg -702.75 | mem length: 5000 | epsilon: 0.0100
# epi: 197 | score avg -710.94 | mem length: 5000 | epsilon: 0.0100
# epi: 198 | score avg -701.23 | mem length: 5000 | epsilon: 0.0100
# epi: 199 | score avg -811.67 | mem length: 5000 | epsilon: 0.0100
# epi: 200 | score avg -805.72 | mem length: 5000 | epsilon: 0.0100
# epi: 201 | score avg -771.47 | mem length: 5000 | epsilon: 0.0100
# epi: 202 | score avg -786.25 | mem length: 5000 | epsilon: 0.0100
# epi: 203 | score avg -738.29 | mem length: 5000 | epsilon: 0.0100
# epi: 204 | score avg -771.16 | mem length: 5000 | epsilon: 0.0100
# epi: 205 | score avg -809.59 | mem length: 5000 | epsilon: 0.0100
# epi: 206 | score avg -868.33 | mem length: 5000 | epsilon: 0.0100
# epi: 207 | score avg -910.09 | mem length: 5000 | epsilon: 0.0100
# epi: 208 | score avg -892.06 | mem length: 5000 | epsilon: 0.0100
# epi: 209 | score avg -950.21 | mem length: 5000 | epsilon: 0.0100
# epi: 210 | score avg -934.65 | mem length: 5000 | epsilon: 0.0100

# %%
env.close()
